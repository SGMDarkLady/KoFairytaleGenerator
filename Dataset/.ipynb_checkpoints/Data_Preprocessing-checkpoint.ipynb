# %%
import pandas as pd
import openpyxl
import numpy as np

import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# # 0. Data Concat

# %%
df = pd.read_excel(r'dataset_정제.xlsx',engine='openpyxl')
df
# Out:
#      Unnamed: 0                                                 동화  \
# 0             0  "나는 알쏭달쏭 미술관 관장 '다다'란다 이곳은 신기하고 괴상한 작품으로 가득하지 ...
# 1             1  2022년 5월 5일은 방정환 선생님이 어린이날을 만든 지 100주년이 되는 날이랍...
# 2             2  5월은 가정의 달이라고 할 만큼 가족들의 소중함을 생각해보게 하는 기념일이 참 많은...
# 3             3  우리 친구들은 또래 친구들을 만나면 보통 어떤 놀이를 하면서 시간을 보내나요?  예...
# 4             4  6월 6일은 나라를 지키기 위해 목숨을 바친 모든 이들의 넋을 기리는 법정 기념일 ...
# ...         ...                                                ...
# 1921        NaN                                                NaN
# 1922        NaN                                                NaN
# 1923        NaN                                                NaN
# 1924        NaN                                                NaN
# 1925        NaN                                                NaN
#
#                                                      정제  Unnamed: 3
# 0     "나는 알쏭달쏭 미술관 관장 '다다'란다. 이곳은 신기하고 괴상한 작품으로 가득하지...         NaN
# 1     방정환은 어려서부터 책을 참 좋아했어요. 다섯 살 때는 할아버지한테 천재문을 배웠죠...         NaN
# 2     텔레비전도 재미있는 그림책도 없었던 옛날의 어린이들은 무엇을 하고 놀았을까요? "옛...         NaN
# 3     "따뜻한 봄바람이 살랑살랑 불고 겨울에 움츠렸던 몸이 움찔움찔. 얘들아 나랑 놀자 ...         NaN
# 4     우리 할아버지입니다. 어려서부터 나는 할아버지와 한 방을 썼어요. 할아버지는 늘 신...         NaN
# ...                                                 ...         ...
# 1921                                                NaN         NaN
# 1922                                                NaN         NaN
# 1923                                                NaN         NaN
# 1924                                                NaN         NaN
# 1925                                                NaN         NaN
#
# [1926 rows x 4 columns]

# %%
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 3', '동화'], axis=1)
df = df.dropna(axis=0)
df = df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   정제      1102 non-null   object
# dtypes: object(1)
# memory usage: 8.7+ KB

# %%
del_index = df.loc[df['정제'] == 'delete'].index
del_index = del_index.values
final_df = df.drop(del_index)
final_df = final_df.reset_index()
final_df = final_df.drop(columns=['index'], axis=1)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   정제      777 non-null    object
# dtypes: object(1)
# memory usage: 6.2+ KB

# %%
final_df.info()
final_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   정제      777 non-null    object
# dtypes: object(1)
# memory usage: 6.2+ KB
#                                                     정제
# 0    "나는 알쏭달쏭 미술관 관장 '다다'란다. 이곳은 신기하고 괴상한 작품으로 가득하지...
# 1    방정환은 어려서부터 책을 참 좋아했어요. 다섯 살 때는 할아버지한테 천재문을 배웠죠...
# 2    텔레비전도 재미있는 그림책도 없었던 옛날의 어린이들은 무엇을 하고 놀았을까요? "옛...
# 3    "따뜻한 봄바람이 살랑살랑 불고 겨울에 움츠렸던 몸이 움찔움찔. 얘들아 나랑 놀자 ...
# 4    우리 할아버지입니다. 어려서부터 나는 할아버지와 한 방을 썼어요. 할아버지는 늘 신...
# ..                                                 ...
# 772  핸드폰 게임 앱을 누르자 선물상자가 나왔다. 선물상자가 열리면서 수많은 옷들과 폭죽...
# 773  그럭저럭 사이좋은 부부가 있었어요. 둘은 같이 식탁을 차렸고, 저녁을 먹은 뒤에는 ...
# 774  비가 개었다. \n동시에 저 편 들판 건너 숲 뒤에는 둥그렇게 무지개가 뻗쳤다. 오...
# 775  여름 장이란 애시당초에 글러서 해는 아직 중천에 있건만 장판은 벌써 쓸쓸하고 더운 ...
# 776  생물 시간이었다. \n“이 없는 동물이 무엇인지 아는가?” \n선생이 두 번씩 거푸...
#
# [777 rows x 1 columns]

# %%
def cleaning(df, column):
    text = df[column]
    clean_text = []
    for i in range(len(text)):
        data = str(text[i])
        data = data.replace('\n'," ")
        data = data.replace('\t'," ")
        clean_text.append(data)
    raw_data = {'동화':clean_text}
    final_dataset = pd.DataFrame(raw_data)
    return final_dataset

# %%
final_df = cleaning(final_df, '정제')
final_df
# Out:
#                                                     동화
# 0    "나는 알쏭달쏭 미술관 관장 '다다'란다. 이곳은 신기하고 괴상한 작품으로 가득하지...
# 1    방정환은 어려서부터 책을 참 좋아했어요. 다섯 살 때는 할아버지한테 천재문을 배웠죠...
# 2    텔레비전도 재미있는 그림책도 없었던 옛날의 어린이들은 무엇을 하고 놀았을까요? "옛...
# 3    "따뜻한 봄바람이 살랑살랑 불고 겨울에 움츠렸던 몸이 움찔움찔. 얘들아 나랑 놀자 ...
# 4    우리 할아버지입니다. 어려서부터 나는 할아버지와 한 방을 썼어요. 할아버지는 늘 신...
# ..                                                 ...
# 772  핸드폰 게임 앱을 누르자 선물상자가 나왔다. 선물상자가 열리면서 수많은 옷들과 폭죽...
# 773  그럭저럭 사이좋은 부부가 있었어요. 둘은 같이 식탁을 차렸고, 저녁을 먹은 뒤에는 ...
# 774  비가 개었다.  동시에 저 편 들판 건너 숲 뒤에는 둥그렇게 무지개가 뻗쳤다. 오묘...
# 775  여름 장이란 애시당초에 글러서 해는 아직 중천에 있건만 장판은 벌써 쓸쓸하고 더운 ...
# 776  생물 시간이었다.  “이 없는 동물이 무엇인지 아는가?”  선생이 두 번씩 거푸 물...
#
# [777 rows x 1 columns]

# %%
final_df.to_csv('dataset_0902.csv')

# %% [markdown]
# # 1. Sentiment Analysis로 부정적 내용 제거

# %%
cd /content/sample_data/DATA/

# %%
DATA_PATH = '/content/sample_data/DATA/'
print('파일 크기: ')
for file in os.listdir(DATA_PATH):
  if 'txt' in file:
    print(file.ljust(30)+str(round(os.path.getsize(DATA_PATH+ file) / 100000,2))+'MB')

# %%
#트레인 파일 불러오기
train_data = pd.read_csv(DATA_PATH + 'ratings_train.txt',header = 0, delimiter = '\t', quoting=3)
train_data.head()

# %%
#리뷰 전체길이 확인
train_length = train_data['document'].astype(str).apply(len)
train_length.head()

# %%
# 문자열 아닌 데이터 모두 제거
train_review = [review for review in train_data['document'] if type(review) is str]
train_review

# %%
#긍정 1, 부정 0
print('긍정 리뷰 갯수: {}'.format(train_data['label'].value_counts()[1]))
print('부정 리뷰 갯수: {}'.format(train_data['label'].value_counts()[0]))

# %% [markdown]
# 데이터 전처리

# %%
import numpy as np
import pandas as pd
import re
import json
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

DATA_PATH = '/content/sample_data/DATA/'
train_data = pd.read_csv(DATA_PATH+'ratings_train.txt', header = 0, delimiter='\t', quoting=3)

# %%
train_data['document'][:5]

# %%
#전처리 함수 만들기
def preprocessing(review, okt, remove_stopwords = False, stop_words =[]):
  #함수인자설명
  # review: 전처리할 텍스트
  # okt: okt객체를 반복적으로 생성하지 않고 미리 생성 후 인자로 받음
  # remove_stopword: 불용어를 제거할지 여부 선택. 기본값 False
  # stop_words: 불용어 사전은 사용자가 직접 입력, 기본값 빈 리스트

  # 1. 한글 및 공백 제외한 문자 모두 제거
  review_text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]','',review)
  
  #2. okt 객체를 활용하여 형태소 단어로 나눔
  word_review = okt.morphs(review_text,stem=True)

  if remove_stopwords:
    #3. 불용어 제거(선택)
    word_review = [token for token in word_review if not token in stop_words]
  return word_review

# %%
# 전체 텍스트 전처리
stop_words = ['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한']
okt = Okt()
clean_train_review = []

for review in train_data['document']:
  # 리뷰가 문자열인 경우만 전처리 진행
  if type(review) == str:
    clean_train_review.append(preprocessing(review,okt,remove_stopwords=True,stop_words= stop_words))
  else:
    clean_train_review.append([]) #str이 아닌 행은 빈칸으로 놔두기

clean_train_review[:4]

# %%
#테스트 리뷰도 동일하게 전처리
test_data = pd.read_csv(DATA_PATH + 'ratings_test.txt', header = 0, delimiter='\t', quoting=3)

clean_test_review = []
for review in test_data['document']:
  if type(review) == str:
    clean_test_review.append(preprocessing(review, okt, remove_stopwords=True, stop_words=stop_words))
  else:
    clean_test_review.append([])

# %%
# 인덱스 벡터 변환 후 일정 길이 넘어가거나 모자라는 리뷰 패딩처리
tokenizer = Tokenizer()
tokenizer.fit_on_texts(clean_train_review)
train_sequences = tokenizer.texts_to_sequences(clean_train_review)
test_sequences = tokenizer.texts_to_sequences(clean_test_review)

word_vocab = tokenizer.word_index #단어사전형태
MAX_SEQUENCE_LENGTH = 8 #문장 최대 길이

#학습 데이터
train_inputs = pad_sequences(train_sequences,maxlen=MAX_SEQUENCE_LENGTH,padding='post')

#학습 데이터 라벨 벡터화
train_labels = np.array(train_data['label'])

#평가 데이터 
test_inputs = pad_sequences(test_sequences,maxlen=MAX_SEQUENCE_LENGTH,padding='post')
#평가 데이터 라벨 벡터화
test_labels = np.array(test_data['label'])

# %%
DEFAULT_PATH  = '/content/sample_data/'
DATA_PATH = 'CLEAN_DATA/'
TRAIN_INPUT_DATA = 'nsmc_train_input.npy'
TRAIN_LABEL_DATA = 'nsmc_train_label.npy'
TEST_INPUT_DATA = 'nsmc_test_input.npy'
TEST_LABEL_DATA = 'nsmc_test_label.npy'
DATA_CONFIGS = 'data_configs.json'

data_configs={}
data_configs['vocab'] = word_vocab
data_configs['vocab_size'] = len(word_vocab) + 1

#전처리한 데이터들 파일로저장
import os

if not os.path.exists(DEFAULT_PATH + DATA_PATH):
  os.makedirs(DEFAULT_PATH+DATA_PATH)

#전처리 학습데이터 넘파이로 저장
np.save(open(DEFAULT_PATH+DATA_PATH+TRAIN_INPUT_DATA,'wb'),train_inputs)
np.save(open(DEFAULT_PATH+DATA_PATH+TRAIN_LABEL_DATA,'wb'),train_labels)
#전처리 테스트데이터 넘파이로 저장
np.save(open(DEFAULT_PATH+DATA_PATH+TEST_INPUT_DATA,'wb'),test_inputs)
np.save(open(DEFAULT_PATH+DATA_PATH+TEST_LABEL_DATA,'wb'),test_labels)

#데이터 사전 json으로 저장
json.dump(data_configs,open(DEFAULT_PATH + DATA_PATH + DATA_CONFIGS,'w'),ensure_ascii=False)

# %%
# 학습 데이터 불러오기
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import json
from tqdm import tqdm

# %%
#전처리 데이터 불러오기
DATA_PATH = '/content/sample_data/CLEAN_DATA/'
DATA_OUT = '/content/sample_data/DATA_OUT/'
INPUT_TRAIN_DATA = 'nsmc_train_input.npy'
LABEL_TRAIN_DATA = 'nsmc_train_label.npy'
DATA_CONFIGS = 'data_configs.json'

train_input = np.load(open(DATA_PATH + INPUT_TRAIN_DATA,'rb'))
train_input = pad_sequences(train_input,maxlen=train_input.shape[1])
train_label = np.load(open(DATA_PATH + LABEL_TRAIN_DATA,'rb'))
prepro_configs = json.load(open(DATA_PATH+DATA_CONFIGS,'r'))

# %%
model_name= 'cnn_classifier_kr'
BATCH_SIZE = 512
NUM_EPOCHS = 10
VALID_SPLIT = 0.1
MAX_LEN = train_input.shape[1]

kargs={'model_name': model_name, 'vocab_size':prepro_configs['vocab_size'],'embbeding_size':128, 'num_filters':100,'dropout_rate':0.5, 'hidden_dimension':250,'output_dimension':1}

# %%
class CNNClassifier(tf.keras.Model):

  def __init__(self, **kargs):
    super(CNNClassifier, self).__init__(name=kargs['model_name'])
    self.embedding = layers.Embedding(input_dim=kargs['vocab_size'], output_dim=kargs['embbeding_size'])
    self.conv_list = [layers.Conv1D(filters=kargs['num_filters'], kernel_size=kernel_size, padding='valid',activation = tf.keras.activations.relu,
                                    kernel_constraint = tf.keras.constraints.MaxNorm(max_value=3)) for kernel_size in [3,4,5]]
    self.pooling = layers.GlobalMaxPooling1D()
    self.dropout = layers.Dropout(kargs['dropout_rate'])
    self.fc1 = layers.Dense(units=kargs['hidden_dimension'],
                            activation = tf.keras.activations.relu,
                            kernel_constraint=tf.keras.constraints.MaxNorm(max_value=3.))
    self.fc2 = layers.Dense(units=kargs['output_dimension'],
                            activation=tf.keras.activations.sigmoid,
                            kernel_constraint= tf.keras.constraints.MaxNorm(max_value=3.))
    

  def call(self,x):
    x = self.embedding(x)
    x = self.dropout(x)
    x = tf.concat([self.pooling(conv(x)) for conv in self.conv_list], axis = 1)
    x = self.fc1(x)
    x = self.fc2(x)
    return x

# %%
from tensorflow.keras.models import save_model

# %%
model = CNNClassifier(**kargs)
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss = tf.keras.losses.BinaryCrossentropy(),
              metrics = [tf.keras.metrics.BinaryAccuracy(name='accuracy')])

#검증 정확도를 통한 EarlyStopping 기능 및 모델 저장 방식 지정
earlystop_callback = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=2)
checkpoint_path = DATA_OUT + model_name +'\weights.h5'
checkpoint_dir = os.path.dirname(checkpoint_path)

if os.path.exists(checkpoint_dir):
  print("{} -- Folder already exists \n".format(checkpoint_dir))
else:
  os.makedirs(checkpoint_dir, exist_ok=True)
  print("{} -- Folder create complete \n".format(checkpoint_dir))

cp_callback = ModelCheckpoint(
    checkpoint_path, monitor = 'val_accuracy', verbose=1, save_best_only = True,
    save_weights_only=True
)

history = model.fit(train_input, train_label, batch_size=BATCH_SIZE, epochs = NUM_EPOCHS,
                    validation_split=VALID_SPLIT, callbacks=[earlystop_callback, cp_callback])

# 모델 저장하기
save_model(model,'/content/sample_data/my_models/')

# %%
# 모델 zip파일로 저장
# !zip -r /content/sample_data/my_models.zip /content/sample_data/my_models/

# %%
# 저장된 모델 zip파일 다운로드
from google.colab import files
files.download('/content/sample_data/my_models.zip')

# %%
INPUT_TEST_DATA = 'nsmc_test_input.npy'
LABEL_TEST_DATA = 'nsmc_test_label.npy'
SAVE_FILE_NM = 'weights.h5'

test_input = np.load(open(DATA_PATH+INPUT_TEST_DATA,'rb'))
test_input = pad_sequences(test_input,maxlen=test_input.shape[1])
test_label_data = np.load(open(DATA_PATH + LABEL_TEST_DATA, 'rb'))

# %%
model.load_weights('/content/sample_data/DATA_OUT/cnn_classifier_kr\weights.h5')
model.evaluate(test_input, test_label_data)

# %%
import csv

# %%
def read_txt(file_path):
    with open(file_path, 'r', encoding ="UTF-8") as f:
        fr = f.read()
    return fr

def read_csv(file_path):
    fr = pd.read_csv(file_path, encoding = "windows-1252")
    return fr

# %%
import pandas as pd

# 여러개 시트를 취득
stories = pd.read_excel('/content/sample_data/DATA/tmp_dataset.xlsx')
stories

# %%
import numpy as np
import pandas as pd
import re
import json
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

negative_story = []

okt = Okt()
tokenizer  = Tokenizer()

DATA_CONFIGS = 'data_configs.json'
prepro_configs = json.load(open('/content/sample_data/CLEAN_DATA/'+DATA_CONFIGS,'r'))
prepro_configs['vocab'] = word_vocab

tokenizer.fit_on_texts(word_vocab)

MAX_LENGTH = 1000 #문장최대길이

#sentence = input('감성분석할 문장을 입력해 주세요.: ')
#print(sentence)
#sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣\\s ]','', sentence)
stopwords = ['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한'] # 불용어 추가할 것이 있으면 이곳에 추가
#sentence = okt.morphs(sentence, stem=True) # 토큰화
#sentence = [word for word in sentence if not word in stopwords] # 불용어 제거
#vector  = tokenizer.texts_to_sequences(sentence)
#pad_new = pad_sequences(vector, maxlen = MAX_LENGTH) # 패딩
#print('변환된 문자 결과값: ',pad_new)
model.load_weights('/content/sample_data/DATA_OUT/cnn_classifier_kr\weights.h5') #모델 불러오기

for i in range(len(stories)):
  sentence = stories[0][i]
  sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣\\s ]','', sentence)
  sentence = okt.morphs(sentence, stem=True) # 토큰화
  sentence = [word for word in sentence if not word in stopwords] # 불용어 제거
  vector  = tokenizer.texts_to_sequences(sentence)
  pad_new = pad_sequences(vector, maxlen = MAX_LENGTH) # 패딩
  predictions = model.predict(pad_new)
  predictions = float(predictions.squeeze(-1)[1])
  #print(predictions)
  if(predictions <= 0.2):
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - predictions) * 100))
    print(sentence)
    negative_story.append([i,stories[0][i],1-predictions])

# %%
negative_story

# %% [markdown]
# # 2. Unsmile로 혐오 표현 데이터셋 제거

# %%
import os
os.getcwd()
# Out:
# 커널을 시작하지 못했습니다.
#
# c:\anaconda3\lib\site-packages\traitlets\traitlets.py:2202: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#
#   warn(
#
# c:\anaconda3\lib\site-packages\traitlets\traitlets.py:2157: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use '41fa80ec-1e9d-4f4d-9351-90667b18a016' instead of 'b"41fa80ec-1e9d-4f4d-9351-90667b18a016"'.
#
#   warn(
#
# Bad file descriptor (bundled\zeromq\src\epoll.cpp:100).
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
import torch

torch.__version__
torch.cuda.is_available()
# !nvidia-smi

# %%
import sys
sys.path

# %%
import gc
import wandb
import pandas as pd
import torch.cuda

# %%
def read_txt(file_path):
    with open(file_path, 'r', encoding ="UTF-8") as f:
        fr = f.read()
    return fr

def read_csv(file_path):
    fr = pd.read_csv(file_path, encoding = "utf-8")
    return fr

# %%
#dataset
tales = []
hansam = read_csv("C:\\Users\\user/SGM_AI/darklady/dataset/[csv]hanguelsam_dataset.csv")
for i in range(len(hansam['동화'])):
    tales.append(hansam['동화'][i])

ollybolly = read_csv("C:\\Users\\user/SGM_AI/darklady/dataset/[csv]ollybolly_story_dataset.csv")
for i in range(len(ollybolly['동화'])):
    tales.append(ollybolly['동화'][i])

bluehouse1 = read_csv("C:\\Users\\user/SGM_AI/darklady/dataset/[csv]bluehouse1.csv")
for i in range(len(bluehouse1['동화'])):
    tales.append(bluehouse1['동화'][i])

bluehouse2 = read_csv("C:\\Users\\user/SGM_AI/darklady/dataset/[csv]bluehouse2.csv")
for i in range(len(bluehouse2['동화'])):
    tales.append(bluehouse2['동화'][i])

bang = read_csv("C:\\Users\\user/SGM_AI/darklady/dataset/[csv]bang_story_dataset.csv")
for i in range(len(bang['동화'])):
    tales.append(bang['동화'][i])

donghwa = read_txt("C:\\Users\\user/SGM_AI/darklady/dataset/[txt]donghwa_korean.txt").split('\n')
for i in range(len(donghwa)):
    tales.append(donghwa[i])
    
print(len(hansam['동화']))
print(len(ollybolly['동화']))
print(len(bluehouse1['동화']))
print(len(bluehouse2['동화']))
print(len(bang['동화']))
print(len(donghwa))
len(tales)

# %%
tmp_dataset = pd.DataFrame(tales)
tmp_dataset.to_csv('tmp_dataset.csv')
tmp_dataset

# %%
stories = tmp_dataset
stories

# %%
# !pip install datasets==1.17.0

# %%
from transformers import AutoTokenizer, AutoModel
from transformers import BertForSequenceClassification, TrainingArguments, Trainer
import torch
import numpy as np

# %%
#smilegate Unsmile dataset
#https://github.com/smilegate-ai/korean_unsmile_dataset
#https://arxiv.org/ftp/arxiv/papers/2204/2204.03262.pdf
#https://colab.research.google.com/drive/1NKYYVSex__vde-lnYCmsRmyHjJhV6cKt?usp=sharing#scrollTo=D75_HqO3V7ZT
from datasets import load_dataset
datasets = load_dataset('smilegate-ai/kor_unsmile')
print(datasets)

datasets["train"][0]
dataset = datasets

# %%
model_name = 'monologg/kobigbird-bert-base'
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def preprocess_function(examples):
    tokenized_examples = tokenizer(str(examples["문장"]))
    tokenized_examples['labels'] = torch.tensor(examples["labels"], dtype=torch.float)
    # multi label classification 학습을 위해선 label이 float 형태로 변형되어야 합니다.
    # huggingface datasets 최신 버전에는 'map' 함수에 버그가 있어서 변형이 올바르게 되지 않습니다.
    
    return tokenized_examples

# %%
tokenized_dataset = dataset.map(preprocess_function)
tokenized_dataset.set_format(type='torch', columns=['input_ids', 'labels', 'attention_mask', 'token_type_ids'])

# %%
tokenized_dataset['train'][0]

# %%
unsmile_labels = ["여성/가족","남성","성소수자","인종/국적","연령","지역","종교","기타 혐오","악플/욕설","clean"]

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
num_labels=len(unsmile_labels) # Label 갯수

model = BertForSequenceClassification.from_pretrained(
    model_name, 
    num_labels=num_labels, 
    problem_type="multi_label_classification"
)
model.config.id2label = {i: label for i, label in zip(range(num_labels), unsmile_labels)}
model.config.label2id = {label: i for i, label in zip(range(num_labels), unsmile_labels)}

# %%
model.config.label2id

# %%
###3. Model training
from sklearn.metrics import label_ranking_average_precision_score

# %%
def compute_metrics(x):
    return {
        'lrap': label_ranking_average_precision_score(x.label_ids, x.predictions),
    }

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
batch_size = 64

args = TrainingArguments(
    output_dir="unsmile_model",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=5,
    save_strategy='epoch',
    load_best_model_at_end=True,
    metric_for_best_model='lrap',
    greater_is_better=True,
)

trainer = Trainer(
    model=model, 
    args=args, 
    train_dataset=tokenized_dataset["train"], 
    eval_dataset=tokenized_dataset["valid"], 
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
    data_collator=data_collator
)

# %%
trainer.train()

# %%
trainer.save_model()

# %%
###4. Model test
#(if you use model after your own fine tuning)
# from transformers import TextClassificationPipeline

# pipe = TextClassificationPipeline(
#     model = model,
#     tokenizer = tokenizer,
#     device=0,
#     return_all_scores=True,
#     function_to_apply='sigmoid'
#     )

# %%
#(if you use original fine-tuned model)
from transformers import TextClassificationPipeline, BertForSequenceClassification, AutoTokenizer,pipeline

model_name = 'smilegate-ai/kor_unsmile'

model = BertForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
classifier = pipeline(task='sentiment-analysis',model=model_name,tokenizer=tokenizer)

pipe = TextClassificationPipeline(
    model=model,
    tokenizer=tokenizer,
    device=0,     # cpu: -1, gpu: gpu number
    return_all_scores=True,
    function_to_apply='sigmoid'
    )

# %%
def get_split(text1):
    l_total = []
    l_partial = []
    if len(text1.split())//40>0:
        n = len(text1.split())//40
    else:
        n=1
    for w in range(n):
        if w==0:
            l_partial = text1.split()[:80]
            l_total.append(" ".join(l_partial))
        else:
            l_partial = text1.split()[w*40:w*40+80]
            l_total.append(" ".join(l_partial))
    return l_total

# %%
split_stories=[]
for i in range(len(stories)):
    split_story = get_split(str(stories[0][i]))
    split_stories.append(split_story)
split_stories

# %%
sentiment = classifier(str(split_stories[0][0]))
print(split_stories[0][0])
print(sentiment)

# %%
이 총을 쏘아대는거야. 많은 사람들이 다치거나 목숨을 잃고 말았지. 그리고 한달쯤 지나 엄청난 소식이 전해졌어. 바다에서 한 학생의 시체가 발견된 거야. 경찰이 사람이 죽은 걸 숨기려고 바다에 던진 거였어. 할아버지의 목소리는 점점 울분으로 가득찼어요. 한 고등학생의 처참한 죽음은 온 국민의 마음을 끓어오르게 만들었답니다. 그리고 4월 19일이 되었어요. 전국의 온 거리가 성난 사람들로 가득찼죠. 교복을 입은 할아버지도 친구와 함께 목이 터져라 외쳤습니다. 이승만 물러가라! 깡패정치 물러가라! 할아버지와 친구는 손을 꼭잡고 계속 앞으로 나갔습니다. 할아버지와 친구에게 총알이 쏟아졌어요. 할아버지는 총에 맞은 다리를 끌며 일어났죠. 하지만 쓰러진 친구는 다시 일어나지 못했습니다. 결국 이승만은 국민들에게 사과하고 대통령직에서 물러났어요.  국민을 무시하고 주인 행세를 한 대통령을 국민의 힘으로 몰아낸 이 사건이 바로 '4.19 혁명'이랍니다. 나라는 한 사람이 자기 욕심대로 다스려서는 안 된단다. 국민의 뜻을 받들어 나라를 다스리는 것, 그게 바로 '민주주의'란다. 4.19혁명을 겪으면서 많은 사람들은 민주주의가 얼마나 소중한 것인지 깨닫게 되었답니다. 이 일이 있은 후에도 총, 칼을 앞세워서 국민들을 위협하고 자기 마음대로 나라를 다스리려는 사람들이 늘 나타났어. 그때마다 국민들은 그런 사람들을 몰아내기 위해 노력했지. 그럼 또 많은 사람들이 다치고 죽었어요? 그렇단다, 우리나라의 민주주의는 쉽게 만들어진 것이 아니야. 많은 사람들의 용기와 희생으로 이루어졌단다. 집으로 돌아갈 시간이 되었어요. 민규는 할아버지의 지팡이를 챙겨 드렸죠. 할아버지, 다리 많이 아프셨죠? 이제 제가 많이 도와드릴게요. 허허~우리 손자가 금방 어른이 되었네! 할아버지는 민규의 머리를 쓰다듬어 주셨어요. 할아버지는 진달래 꽃을 보면 자꾸 친구 생각이 난답니다. 오늘 할아버지의 친구 이야기를 들으며 민규는 마음속 깊이 4월의 진달래꽃을 심었답니다. 학생과 시민의 희생으로 피운 꽃 민주주의 소중하고 감사한 마음으로 앞으로도 잘 지켜나가야 할 것입니다."):
#    print(result)
classified_df = []
list=[]
for i in range(len(stories)):
    list=[]
    for j in range(len(split_stories[i])):
        for sentiment in pipe(str(split_stories[i][j])):
            list.append(sentiment)       
    classified_df.append(list)

# %%
for result in pipe("이래서 여자는 게임을 하면 안된다."):
    print(result)

# %%
k=classified_df[0][0].values()

# %%
mylist = []
on_score=0.0
for i in range(len(classified_df)):
    list=[]
    for j in range(len(classified_df[i])):
        or_score=classified_df[i][j]
        for k in range(10):
            score = or_score[k]['score']
            list.append(score)
        mylist.append(list)
mylist

# %%
lenght=0
data = []
sentiment=[]
for i in range(len(mylist)):
    list={}
    sentiment_book=[]
    a=float(0)
    b=float(0)
    c=float(0)
    d=float(0)
    e=float(0)
    f=float(0)
    h=float(0)
    k=float(0)
    l=float(0)
    m=float(0)
    for j in range(len(mylist[i])):
        score = mylist[i][j]
        length = len(mylist[i])/10
        if j%10==0:
            a+=score
        if j%10==1:
            b+=score
        if j%10==2:
            c+=score
        if j%10==3:
            d+=score
        if j%10==4:
            e+=score
        if j%10==5:
            f+=score
        if j%10==6:
            h+=score
        if j%10==7:
            k+=score
        if j%10==8:
            l+=score
        if j%10==9:
            m+=score
    list['여성/가족']=a/length 
    list['남성']=b/length 
    list['성소수자']=c/length 
    list['인종/국적']=d/length 
    list['연령']=e/length 
    list['지역']=f/length 
    list['종교']=h/length 
    list['기타 혐오']=k/length 
    list['악플/욕설']=l/length 
    list['clean']=m/length 
    data.append(list)
    fin_max = max(list, key=list.get)
    sentiment_book.append(fin_max)
    sentiment_book.append(list[fin_max])
    #sentiment_book[fin_max]=list[fin_max]
    sentiment.append(sentiment_book)

# %%
unclean = []
for n in range(1101):
    data = sentiment[n][0]
    #dict_val = list(data.values())
    if data != 'clean':
        unclean.append(n)
        unclean.append(sentiment[n][0])
        unclean.append(sentiment[n][1])
        unclean.append(str(stories[0][n]))
unclean

# %% [markdown]
# # 3. Gender Swapping Data Augmentation(선택)

# %%
df = pd.read_csv('dataset_0902.csv', encoding='UTF-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  777 non-null    int64
#  1   동화          777 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 12.3+ KB

# %% [markdown]
# ## 3-1) 익명화
# 동화 데이터에 등장하는 등장인물들의 이름을 익명화합니다. 이름에 의한 성별 고정관념을 없애는 과정입니다.
# <br>각 인물별로 번호를 메겨 E(번호) 형태의 토큰으로 대체합니다.

# %%
name_list = pd.read_csv('gender_swapping/character.txt')['인물']
name_list
# Out:
# 0       다다
# 1      방정환
# 2      손기정
# 3       선미
# 4      반쪽이
#       ...
# 227    바오밥
# 228    마룰라
# 229    와르다
# 230     롤리
# 231     월터
# Name: 인물, Length: 232, dtype: object

# %%
def anonymize(text, name_list):
    for i in range(len(name_list)):
        #new_name = '인물' + str(i)
        text = text.replace(name_list[i], '<인물' + str(i) +'>')
    return text

# %%
anonymized_data = []
for i in range(len(df['동화'])):
    story = str(df['동화'][i])
    text = anonymize(story, name_list)
    anonymized_data.append(text)
    
data = {'동화':anonymized_data}
anonymized_df = pd.DataFrame(data)

# %%
#제대로 익명화되었는지 확인하기
print('원본 데이터:', len(df['동화']), 'anonymized 데이터:', len(anonymized_df))
print(
    '원본 데이터 "방정환" 등장 수:', 
      len(df[df['동화'].str.contains('방정환', na=False)]),
      df.index[df['동화'].str.contains('방정환', na=False)].tolist()
)
print(
    'anonymized 데이터 "방정환" 등장 수:',
      len(anonymized_df.query('동화.str.contains("<인물1>")')),
     anonymized_df.index[anonymized_df['동화'].str.contains('<인물1>', na=False)].tolist()
)
# Out:
# 원본 데이터: 777 anonymized 데이터: 777
# 원본 데이터 "방정환" 등장 수: 2 [1, 2]
# anonymized 데이터 "방정환" 등장 수: 2 [1, 2]

# %% [markdown]
# ## 3-2) 여성어/남성어 바꾸기
# 1. 엄마/아빠, 할머니/할아버지, 공주/왕자 등 단어에 성별을 유추할 수 있는 단어들을 sawpping합니다. 이를 통해 주어 뒤에 서술되는 요소가 주어의 성별에 영향을 받지 않도록 만듭니다.
# 2. '여배우(=배우)', '하녀(=하인)'처럼 stem이 되는 단어가 보편적 기준으로서 남성을 지칭하고, 여성을 지칭하기 위해 단어의 앞이나 뒤에 '-여'를 붙인 단어들을 stem이 되는 단어로 바꿉니다.

# %%
#word_list 정의
female_word_list = [
    '엄마', '할머니', '여왕', '공주', '그녀', '여신', '하녀', '여학생', '의붓어머니', '계모', '마녀',
    '여자아이', '간호사', '여의사','그녀', '신부', '과부', '미망인', '소녀', '모성애', '아내', '집사람', '손녀',
    '처녀', '여자친구', '딸', '언니', '누나','새언니', '숙녀', '여성'
]

male_word_list = [
    '아빠', '할아버지', '왕', '왕자', '그', '신', '하인', '학생', '의붓아버지', '계부', '마법사',
    '남자아이', '의사','의사', '그', '신랑', '홀아비', '홀아비', '소년', '부성애', '남편', '바깥사람', '손자',
    '총각', '남자친구', '아들', '오빠', '형','새오빠', '신사', '남성'
]

조사_list = ['께', '에게', '한테', '더러', '에서','의',
          '에게서', '한테서', '와', '하고', '처럼', '같이', '보다',
          '만큼', '도']

#은/는, 이/가는 수작업으로 붙인다.
additional_female_word_list = [
    '엄마는', '엄마가', '할머니는', '할머니가', '여왕이', '여왕은', '공주가', '공주는', '그녀가', '그녀는', '여신이', '여신은'
    '하녀가', '하녀는', '여학생은', '여학생이', '의붓어머니가', '의붓어머니는', '계모가', '계모는', '마녀가', '마녀는',
    '여자아이가', '여자아이는', '간호사가', '간호사는', '여의사가', '여의사는','그녀는', '그녀가', '신부는', '신부가', '과부가', '과부는', '미망인은','미망인이',
    '소녀가', '소녀는','모성애가', '모성애는', '아내는', '아내가', '집사람이', '집사람은', '손녀는', '손녀가', '처녀가', '처녀는',
    '여자친구가', '여자친구는','딸은', '딸이', '언니가', '언니는', '누나가', '누나는', '새언니가', '새언니는', '숙녀가', '숙녀는',
    '여성이', '여성은']

additional_male_word_list = [
    '아빠는', '아빠가', '할아버지는', '할아버지가', '왕이', '왕은', '왕자가', '왕자는', '그가', '그는', '신이', '신은'
    '하인이', '하인은', '남학생은', '남학생이', '의붓아버지가', '의붓아버지는', '계부가', '계부는', '마법사가', '마법사는',
    '남자아이가', '남자아이는', '의사가', '의사는', '의사가', '의사는', '그는', '그가', '신랑은', '신랑이', '홀아비가', '홀아비는', '홀아비는','홀아비가',
    '소년이', '소년은','부성애가', '부성애는', '남편은', '남편이', '바깥사람이', '바깥사람은', '손자는', '손자가', '총각이', '총각은',
    '남자친구가', '남자친구는','아들은', '아들이', '오빠가', '오빠는', '형이', '형은', '새오빠가', '새오빠는', '신사가', '신사는',
    '남성이', '남성은']

# %%
def add_grammer(origin_word_list, additional_list):
    final_word = []
    for i in range(len(origin_word_list)):
        for n in range(len(조사_list)):
            word = str(origin_word_list[i])+str(조사_list[n])
            final_word.append(word)
    for x in range(len(additional_list)):
        final_word.append(additional_list[x])
    return final_word

# %%
final_female_word_list = add_grammer(female_word_list, additional_female_word_list)

final_male_word_list = add_grammer(male_word_list, additional_male_word_list)

# %%
print(final_female_word_list)
�같이', '숙녀보다', '숙녀만큼', '숙녀도', '여성께', '여성에게', '여성한테', '여성더러', '여성에서', '여성의', '여성에게서', '여성한테서', '여성와', '여성하고', '여성처럼', '여성같이', '여성보다', '여성만큼', '여성도', '엄마는', '엄마가', '할머니는', '할머니가', '여왕이', '여왕은', '공주가', '공주는', '그녀가', '그녀는', '여신이', '여신은하녀가', '하녀는', '여학생은', '여학생이', '의붓어머니가', '의붓어머니는', ...

# %%
def preprocessing(text, origin_word_list):
    for i in range(len(origin_word_list)):
        text = text.replace(origin_word_list[i], '*'+origin_word_list[i])
    return text

# %%
def gender_swapping(text, origin_word_list, swapped_word_list):
    for i in range(len(origin_word_list)):
        text = text.replace('*'+origin_word_list[i], swapped_word_list[i])
    return text

# %%
swapped_data = []
for i in range(len(df)):
    story = str(anonymized_df['동화'][i])
    f_to_m = preprocessing(story, final_female_word_list)
    m_to_f = preprocessing(f_to_m, final_male_word_list)
    f_to_m_swapped = gender_swapping(m_to_f, final_female_word_list, final_male_word_list)
    m_to_f_swapped = gender_swapping(f_to_m_swapped, final_male_word_list, final_female_word_list)
    swapped_data.append(m_to_f_swapped)
    
data = {'동화':swapped_data}
gender_swapped_df = pd.DataFrame(data)

# %%
#제대로 swapped되었는지 확인
print('원본 데이터:', len(df['동화']), 'swapped 데이터:', len(gender_swapped_df))
print('원본 데이터 할머니 단어 수:', len(df[df['동화'].str.contains('할머니가', na=False)]))
print('원본 데이터 할아버지 단어 수:', len(df[df['동화'].str.contains('할아버지가', na=False)]))
print('swapped 데이터 할머니 단어 수:', len(gender_swapped_df.query('동화.str.contains("할머니가")')))
print('swapped 데이터 할아버지 단어 수:', len(gender_swapped_df.query('동화.str.contains("할아버지가")')))
# Out:
# 원본 데이터: 777 swapped 데이터: 777
# 원본 데이터 할머니 단어 수: 71
# 원본 데이터 할아버지 단어 수: 62
# swapped 데이터 할머니 단어 수: 62
# swapped 데이터 할아버지 단어 수: 71

# %%
gender_swapped_df['동화'][0]
# Out:
# '"나는 알쏭달쏭 미술관 관장 \'<인물0>\'란다. 이곳은 신기하고 괴상한 작품으로 가득하지. 재미있는 미술 작품들이 가득한 알쏭달쏭 미술관에 온 걸 환영합니다." "이쪽에 있는 변기를 볼래? 화장실에서나 볼 수 있는 변기가 미술 작품이라면 믿겠니?" "네? 변기가 미술 작품이라구요?" "너희들 모나리자란 그림을 알고 있지? 레오나르도 다빈치가 그린 그림이야. 그런데 뒤샹이라는 화가는 모나리자의 얼굴에 수염만 그리고 전시를 했단다. 그래서 사람들은 깜짝 놀랐지." "네? 유명한 작품에 낙서를 한 게 미술 작품이라구요?" "뒤샹은 장난꾸러기였나봐. 그럼 이거는 뭘 그린 건지 한번 맞춰볼래? 여러 색깔의 물감을 뿌리고 붓고 흘린 거란다. 곳곳에 커다란 물감 얼룩도 있지." "폴록이라는 화가는 이게 연보라빛 안개라는구나. 그런데 미술관 관장인 내가 봐도 신나게 물감을 뿌려 놓은 것 같거든 혹시 너희들 눈에는 안개가 보이니?" "글쎄요? 보이는 것도 같고 아닌 것 같기도 하고.." "그렇게 볼록은 커다란 종류의 물감을 쏟아 부었어. 그리고 붓을 휘젓고 물감을 튀겼지. 가끔은 물감 대신 모래를 톡톡 뿌리기도 했단다. 진짜 신났겠지?" "물감을 가지고 장난치는 것 같아..." "화가 에른스트는 물건의 종이를 대고 문지르면서 작품을 만들었어. 어떤 물건이냐에 따라 무늬가 달라지지!" "에이 이건 나도 그릴 수 있을 것 같아." "종이에 물감을 쭉 짜놓고 접었다가 펴면 양쪽에 똑같은 그림이 나타나지 이걸 \'데칼코마니\'라고 한단다." "이 그림은 어떠냐 이것도 미술 작품이야. 리엔텐 슈타인은 만화의 한 장면에 검은 선을 그린 다음 알록달록 색칠을 했단다. 진짜 만화책처럼 보이려고 촘촘히 작은 점도 찍었어." "관장님 저도 만화책으로 작품을 만들어 볼래요!" "그리고 리히텐슈타인은 말풍선 안에 글도 넣었단다. 누구나 알기 쉽게 재미있는 그림을 그리고 싶었던 거야. 어때 만화를 보는 것처럼 쉽지?" "네 꼭 만화책 같아요." "햄버거와 막대 아이스크림을 미술 작품이라고 전시한 미술가도 있단다. 먹고 싶다기보다는 깔고 앉고 싶지." "물론 절대로 먹을 수는 없어 고무와 상자 천으로 만들어졌거든." "야 이런 것도 현대미술이구나. 어 갑자기 배가 고파져." "화가 올덴버*그녀는 반대로 생각하는 걸 좋아했단다. 사람이나 눈물 대신 물건이나 음식을 조각으로 만들었어. "숟가락, 미끄럼틀, 먹다 버린 사과, 배드민턴 공 이런 재료들이 모두 미술이 되었지. 재료도 이것저것 써서 작은 곳은 엄청 크게 단단한 곳은 물렁물렁하게 만들었단다." "먹다 버린 사과가 멋진 작품이 된 거야." "심심해서 끄적거리는 것도 미술이 될까?" "화가 바스키아는 지하철과 길거리 벽에 글을 쓰고 그림을 그렸어. 아프리카 가면을 닮은 얼굴이랑 글자 화려한 색깔과 모양이 어우러져 활기찬 그림이 되었지." "낙서가 예술 작품이 될 수 있다구요? 어 그럼 나도 벌써 예술간데..?" "스미스슨이라는 화가는 호수의 빙글빙글 달팽이 집 모양 둑을 만들었어. 이건 비행기를 타야 볼 수 있겠지. "저기요 저기 멋진 둑이 보여요." "이 둑은 물에 잠기기도 하고 부서지거나 깎이면서 조금씩 없어진단다. 이런 것까지도 작품이라고 생각했단다. 현대 미술가들은 톡톡 튀는 생각 톡톡 튀는 방법으로 작품을 만들어요." "허스트는 죽은 동물이나 알약으로 죽음을 표현했단다." "그런데 이게 모두 미술이 맞는 걸까?" "미술이 그림을 그리는 것만은 아닌가 봐요. 그래 맞아. 현대 미술가들은 자기가 그리고 싶은 대로 그리고 만들고 싶은 대로 만들지. 우리는 그냥 보이는 대로 느끼면 된단다." 정말 생각지도 않았던 것들이 미술 작품으로 전시되어 있었어요. 이렇게 현대미술은 표현 방법이나 주제 또 재료와 도구들이 아주 아주 다양해졌답니다.'

# %%
gender_swapped_df.to_csv('swapped_data_0902.csv', encoding='UTF-8')

# %% [markdown]
# # 4. Labeling
# seq2seq 모델에 적용하기 위해 데이터셋의 앞 두 문장을 input으로, 스토리 전체를 target으로 학습 데이터를 수정합니다.

# %%
df = pd.read_csv('swapped_data_0902.csv')
df = df.dropna(axis=0)
df = df.drop(index=343, axis=0)
#df = df.drop(index=303, axis=0)
df = df.drop(df.columns[0], axis=1)
df = df.reset_index(drop=True)
df
# Out:
#                                                     동화
# 0    "나는 알쏭달쏭 미술관 관장 '<인물0>'란다. 이곳은 신기하고 괴상한 작품으로 가...
# 1    <인물1>은 어려서부터 책을 참 좋아했어요. 다섯 살 때는 할머니한테 천재문을 배웠...
# 2    텔레비전도 재미있는 그림책도 없었던 옛날의 어린이들은 무엇을 하고 놀았을까요? "옛...
# 3    "따뜻한 봄바람이 살랑살랑 불고 겨울에 움츠렸던 몸이 움찔움찔. 얘들아 나랑 놀자 ...
# 4    우리 할아버지입니다. 어려서부터 나는 할머니와 한 방을 썼어요. 할머니는 늘 신문을...
# ..                                                 ...
# 771  핸드폰 게임 앱을 <인물153>자 선물상자가 나왔다. 선물상자가 열리면서 수많은 옷...
# 772  그럭저럭 사이좋은 부부가 있었어요. 둘은 같이 식탁을 차렸고, 저녁을 먹은 뒤에는 ...
# 773  비가 개었다.  동시에 저 편 들판 건너 숲 뒤에는 둥그렇게 무지개가 뻗쳤다. 오묘...
# 774  여름 장이란 애시당초에 글러서 해는 아직 중천에 있건만 장판은 벌써 쓸쓸하고 더운 ...
# 775  생물 시간이었다.  “이 없는 동물이 무엇인지 아는가?”  선생이 두 번씩 거푸 물...
#
# [776 rows x 1 columns]

# %%
def split_to_sentences(text):
    """
    Args: 
        text (str): raw text to split to sentences on end of sentences marks.
    Returns:
        List of sentences from text.
    """
    # Split on end of sentence, but keep the punctuation marks.
    text = text.replace('\n', '')
    sentences = text.split('.')
    # If the last sentence is ''
    if len(sentences) > 1 and len(sentences[-1]) < 3:
        sentences.pop()
    return sentences

# %%
labels = []
for i in range(len(df)):
    text = df['동화'][i]
    sentences = split_to_sentences(text)
    if len(sentences) < 2:
        print(i)
        i +=1
    else:
        label = sentences[0] + '.' + sentences[1]
        labels.append(label)
labels
# Out:
# ['"나는 알쏭달쏭 미술관 관장 \'<인물0>\'란다. 이곳은 신기하고 괴상한 작품으로 가득하지',
#  '<인물1>은 어려서부터 책을 참 좋아했어요. 다섯 살 때는 할머니한테 천재문을 배웠죠',
#  '텔레비전도 재미있는 그림책도 없었던 옛날의 어린이들은 무엇을 하고 놀았을까요? "옛날에 어린이들은 아마 굉장히 심심하고 외로웠을 거야." "그런데 어린이라는 말은 어떻게 생겨났을까?" 그럼 지금부터 어린이라는 말과 어린이 날이 어떻게 생겼는지 옛날 이야기를 들어볼까요',
#  '"따뜻한 봄바람이 살랑살랑 불고 겨울에 움츠렸던 몸이 움찔움찔. 얘들아 나랑 놀자 어깨동무 씨 동무 하자',
#  '우리 할아버지입니다. 어려서부터 나는 할머니와 한 방을 썼어요',
#  '<인물3>네 집 뒷편에 아주 아주 작은 집이 또 하나 있어요. 바로 생쥐네 집이었죠',
#  '우리 집에 나무가 있다면 정말 좋을거야. 봄이면 아름다운 꽃이 피겠지',
#  '어느 연못에 개구리들이 살고 있었어요. 개구리들은 비를 맞으며 개골개골 노래 부르는 것을 아주 좋아했답니다',
#  '우리는 생선을 좋아해요. 고기도 좋아하고요',
#  '내 이름은 까만 내리노예요. 우리 가족은 엄마하고 엄마 그리고 누나가 넷이랍니다',
#  '꽃방귀가 퐁퐁퐁 바람이 산들산들 부는 언덕에 예쁜 꽃들이 살았어요. 바람이 불면 꽃 향기가 저 멀리 마을에까지 퍼졌죠',
#  '내가 괴물이라고? 괴물이야 괴물. 빨리 날아가자',
#  '어느 날 밤 하늘을 환히 밝히던 달님이 투덜댔어요. "아우, 힘들어',
#  '마샤가 없을 때 라이오넬은 신나게 놀지. “마샤야, 네가 학교에 가면 너는 내가 하루 종일 잠만 잘 거라고 생각하겠지? 정말 그럴까? 내가 너에게 새로운 사실을 알려줄게',
#  '만희의 집은 동네에서 나무와 꽃이 가장 많은 집이었어요. 만희가 유치원에서 돌아오면 개들은 발자국 소리만 듣고도 만희를 알아봤죠',
#  '맥기 아저씨가 아름<인물132> 사과나무 아래에서 홍차를 마시고 있었어요. 그때 큰 먹구름이 사과나무 위를 지나가고 있었답니다',
#  '안나는 무서울 때 어떻게 하는지 아세요? 자기를 지켜줄 친구들을 부른답니다. 절대로 잠을 안자는 커다란 거인을 부르고요',
#  '옛날 옛날에 머나먼 인도 땅에 한 여왕이 있었습니다. 이 여왕은 좋아하는 거라면 무엇이든 다 가졌지만 싫어하는 것이 딱 하나 있었어요',
#  '"아니, 돼지야. 어떻게 된 거야? 쫄딱 젖었잖아',
#  '"어디 사냥을 시작해 볼까? 음, 사냥감은 어디에 있는 거지? 아 도대체 어디에 있는 거야?" "이 바보야. 뒤에 있는데도 안 보이냐?" "여기에 있을까?" "글쎄…날 찾을 수 없을껄?" "저기에 있나?" "어디 한번 찾아보라고',
#  '생쥐하고 영화보러 간다면 생쥐하고 영화를 보러 간다면 아마 팝콘을 사달라고 조를 거예요.  그래서 팝콘을 한 통 가득 사다 주면 그걸 모두 한 줄에 꿰어놓겠죠',
#  '새해, 새날, 새 아침. 뭐든 새로 시작하는 첫 번째 날이에요',
#  '에롤은 도시에 사는 생쥐예요.  하수구를 따라서 꼬질꼬질한 생쥐 학교에 다니죠',
#  '옛날 아주 먼 옛날, 땅 속 깊은 곳에 커다란 성이 하나 있었어요.  이 성에 사는 임금님은 뭐든지 뜨거운 것만 좋아했어요',
#  '귀여운 다람쥐 무크는 오줌싸개 대장이랍니다. 오늘도 나뭇가지에 이불이 널려 있네요',
#  '최고의 약은 물이라고 우리 할아버지가 말씀하셨어요.  우리는 물에서 왔다고',
#  '어느 날 아침 찬이는 갑자기 느림보로 변했어요.  밥 먹는 것도 느릿느릿',
#  '얘들아 점심 먹으러 가자.  깡충 올라타서 문을 닫고 안전띠를 매요',
#  ' 들쥐가 옷을 벗고 잠자리에 들려고 해요.  들쥐는 침대에 누웠죠',
#  '어디선가 들려오는 쿵짝쿵짝 신나는 비트 소리. 춤추는 것을 너무도 좋아하는 사자 브라이언은 리듬에 맞춰 몸을 움직이죠',
#  '캥거루도 아빠가 있을까?  그럼. 캥거루도 아빠가 있지',
#  '어느 날 아침 가스통이 학교에 가다가 엄마에게 물었어요. "아빠',
#  '네모가 있었어요. 똑같이 생긴 옆면이 네 개이고 똑같이 생긴 모서리도 네 개인 정사각누나가었죠',
#  '시끄러운 소리에 아침부터 짜증이 났어. 귀찮게 매달려서 그런 건데 아빠는 또 나만 혼냈어',
#  '동희는 여신이 났어요.  기차 타고 바다로 여행을 떠나거든요',
#  '산책을 하던 어느 날 작은 아이가 엄마를 바라보며 물었어. "엄마',
#  '우거진 숲속 디플로도쿠스의 둥지에요.  엄마 공룡이 둥지를 비운 사이에 아기 공룡들이 태어났답니다',
#  ' 하루는 가스통이 선생님한테 물었어요. "선생님 우리는 왜 모두 다르게 생겼어요?" "모든 사람이 똑같이 생겼다고 생각해 보렴 공장에서 찍어낸 물건들처럼 다 똑같다면 가스통이 누구인지 찾아낼 수 없을걸?" "맞아요',
#  ' "달나라에 갈 수 있을까요?" 아기 곰이 물었어요.  "못 가지',
#  '완두는 아주 작은 세상에 살고 있어요.  그래도 필요한 건 모두 있답니다',
#  '우리 엄마는 산처럼 커요 아침마다 엄마가 나를 유치원에 데려다주면 친구들은 놀라고 난답니다.  "너희 엄마가 무슨 일 해?" 친구들이 다가와 물었어요',
#  '옛날 옛날에 한 임금님이 있었어요.  아주 작은 임금님이었죠',
#  '바닷속 한 구석에 작은 물고기들이 떼를 지어 행복하게 살고 있었습니다.  모두 빨간색 물고기들이었죠',
#  '엄마는 이제 큰일 났어 깜빡 잊고 루이의 생일 선물을 못 샀거든. "벤자민 것보다 더 큰 곰을 선물해 주기로 약속했잖아요',
#  '예술가가 별을 그렸어요.  아주 멋진 별이었죠',
#  ' 너무 큰 목소리로 말할 순 없지만 나는 도둑이에요.  밤이 되면 자루를 매고 불이 나게 집을 나가는 수상한 도둑이랍니다',
#  '이렇게 되면 참 좋겠다. 콧구멍을 후비면 다이아몬드가 쑥 나오고 귓 볼을 자꾸 만지면 나의 길처럼 커져서 하늘을 날 수 있으면 좋겠어',
#  '어느 화창한 봄날 병아리 한 마리가 태어났어 아주 튼튼해 보이는 수평아리였지. 이 수평아리는 보기만큼이나 씩씩했어 달리기도 높이 뛰기도 이 병아리를 따를 병아리가 없었단다 곧 동네에서 제일 힘센 병아리가 되었어',
#  '옛날 어느 나라에 수다쟁이 임금님이 있었어요.  임금님은 쉼없이 말을 했죠',
#  '하얀 눈이 소복이 쌓인 날 솔이가 아빠에게 물었어요. "아빠는 겨울에 뭐 하고 놀았어?" 아빠는 말이야 오늘처럼 눈이 오는 날은 귀여신같이 알아차렸지',
#  '옛날에 스리랑카 사람들은 수염을 길게 길렀어요.  긴 수염이 좋아서가 아니었죠',
#  '피터는 몸이 아팠어요. 머리에서 열이 나고 눈이 따끔따끔 아팠죠',
#  '나는 아빠 섬에 사는 나무예요. 나는 아주 아주 쑥쑥 커질 수 있어요',
#  '안녕하세요. 내 이름은 엘엠엔오피오에요',
#  '찬바람이 윙윙 불어 숲의 나무도 호수의 물도 꽁꽁 얼어버릴 만큼 아주 아주 추운 겨울날이었어요.  그때 바퀴 번쩍번쩍하더니 쿵 하는 소리가 났죠',
#  '크리스마스까지 다섯 밤이 남았어요.  휘리릭 굴뚝으로 뭔가가 떨어졌죠',
#  '아주 먼 옛날 하늘의 별들이 생겨나기 전의 일이에요.  작은 새 한 마리가 깜깜한 어둠 속을 날아가다 빛을 보았습니다',
#  '에버는 노아 할머니와 노아 할머니를 도와서 방주를 만들었어요.  보세요',
#  '캄캄해  아 아무것도 안 보여 뭐든 나갔으니 어서 밖으로 나가자 재재의 신발장 안에서 시끌벅적 떠도는 소리가 들렸어요.  신발장 문이 열리더니 우산 세 개가 우당탕퉁당 우산 속에 숨어 있던 색깔 요정들이 신나게 춤추며 노래했죠',
#  ' 생쥐 마틴이랑 고양이 클라라 강아지 후버는 세상에서 제일 친한 친구랍니다.  셋은 언제나 함께 있고 싶었죠',
#  '초록빛 이파리에 작은 초록빛 카멜레온이 앉아 있었습니다.  카멜레온는 갈색 나뭇가지로 옮겨가더니 갈색이 되었습니다',
#  '어느 화창한 봄날이었어요.  아기 곰 부부는 겨울잠에서 깨어나 처음으로 굴 밖으로 나왔죠 온통 신기한 것들 뿐이어서 이것저것 볼 것이 많았답니다',
#  '"나무를 베어서 새 집을 지어야지."  나무꾼이 숲으로 갔습니다',
#  '옛날 아주 먼 옛날. 하늘나라를 다스리는 옥황상제에게 <인물14>라는 어여쁜 외동아들이 하나 있었어요',
#  '다음 날 아침 <인물133>는 물소에게 말했어요. "네가 나와 함께 가지 않아도 나는 떠나야 할 것 같아',
#  '옛날 옛적 어느 숲 속에 ‘뚜우’라는 부엉이가 살고 있었어요. 뚜우는 아직 어려서 몸집이 작았지만 부엉이가 해야 하는 일을 하나도 빠짐없이 하고 싶어 했어요',
#  '하늘에서 흰 눈이 펑펑 내리면 눈<인물16>처럼 새하얀 토끼 한 마리가 곰곰이 생각에 잠긴답니다. "평범한 건 싫어 어떻게 하면 특별한 토끼가 될까?" 청둥오리들은 나란히 줄을 지어 해저무는 하늘을 훨훨 날아요',
#  '흙은 언제나 꿈을 꾸고 있어요. 숲이 될 거예요',
#  '작고 하얀 펭귄은 외톨이. "다른 애들은 회색과 까만색이 섞여 있는데 나만 새하얘',
#  '햇살이 반짝반짝 비치고 바람이 살랑살랑 부는 날이었어. "오, 순무를 심기 딱 좋은 날인걸',
#  '어떤 할머니에게 순무 씨가 있었어요. 어느 날 할머니가 그 순무 씨를 심었어요',
#  '우리 아빠는 늘 똑같은 옷만 입어. 청바지에 티셔츠',
#  '먼 옛날 어느 작은 왕국에 라나 왕자가 살았어요. 볼이 발그레, 웃을 때 가지런한 이가 드러나는 귀여운 공주',
#  '옛날에 바보 같지만 마음씨 착한 ‘이반’이 농사를 지으며 살았어. 이반에게는 집을 떠나 떵떵거리며 사는 두 누나가 있었지',
#  '"흐흑…. 어떡하지',
#  '반짝반짝 작은 별에 차차, 푸푸, 고고가 살았어요. 세 친구는 사이가 아주 좋았어요',
#  '집 앞까지 하나, 둘, 셋, 넷, 다섯, 여섯, 일곱, 여덟, 아홉, 열 걸음. 집에 가는 길이에요',
#  '내 입안에 충치균이 산다고요? 아무리 봐도 치아밖에 없는데. 사탕, 과자, 이런 걸 먹으면 입안에 있는 충치균이 똥을 싼다고요? 하얀 이에 누런 똥 우리 모두의 입안에는 이백억 마리의 구강 미생물이 살고 그중에 충치균이 포함되어 있는 거라고요? 200억 마리가 똥을 뿌지직? 으, 싫어 싫어 싫어',
#  '말랑말랑, 새콤달콤. 꼬마생쥐 까모는 젤리를 참 좋아해요',
#  '조물락 조물락. 길쭉 꼬리',
#  '여기는 꼬마 개들이 다니는 왈왈 유치원. "가운데 선 넘지마!" "누가 할 소리! 너야말로 조심해',
#  '"오… 오늘은 공주랑 놀… 고 싶…" 임금님은 언제나 말을 우물우물. 신하들은 무슨 말인지 알아들을 수가 없었어요',
#  '다연이는 베란다에 꼭 붙어서 손을 흔들고 또 흔들었어요. 아빠는 동생을 낳으러 병원에 갔어요',
#  '나는 뾰족이. 히히히히 오늘은 내가 유치원 대장이야',
#  '걱정 아저씨네 우편함에 편지가 왔어요. 다행 아저씨가 보냈어요',
#  '내 이름은 김아영. 새로 산 원피스! 오늘 유치원에 입고 가면 친구들이 뭐라고 할까? 그런데 친구들은 나를 보자마자 "김하영 공주 옷 입었구나! 돼지공주!" "돼지공주!" "난 돼지가 아니라 그냥 통통한 건데',
#  '고은이네 집이 북적북적, 온 가족이 모였어요. 오늘은 고은이의 생일이거든요',
#  '월요일 아침이에요. "은비야 빨리 일어나',
#  '꼬마곰이 숲속을 걸어가고 있었어요. 늑대가 군침을 흘리며 튀어나오자 꼬마곰이 마술 연필을 지그재그',
#  '"음… 너 이발 좀 해야겠는데?" "아니에요. 괜찮아요',
#  '우리 아들이에요. 우리 아들은 동물을 좋아해요',
#  '세상에서 가장 게으른 아이를 알고 있나요? 바로 로로예요. 얼마나 움직이기 싫어하는지 몸을 한 번 뒤집는데도 한참이 걸린답니다',
#  '개나리 반 친구들이 모두 모였어요. 그런데 선생님이 자리를 비운 사이 재호가 오줌을 싸고 말았네요',
#  '옛날 옛날에 여동생과 언니가 살았어요. 둘은 비슷한 데가 하나도 없었어요',
#  '"공격!" 도<인물85>와 도진이가 미끄럼틀로 뛰어가요. 미끄럼틀 위에는 건우 누나가 버티고 있어요',
#  '"김경우 휴대폰 이리 줘!" 신나게 너구리 게임을 하던 경우의 얼굴이 울상이 되었어요. "조금만, 조금만 더 하면 안돼?" "삼십 분 하기로 약속했잖아, 안돼',
#  '"아이, 어떡해, 어떡해…." 발표회가 아직 멀었는데도 민지는 가슴이 콩닥콩닥',
#  '나는 밤이 싫어요. 밤은 무섭고 심심하거든요',
#  '생쥐들이 사는 마을에 고양이가 나타난 이후로 생쥐들은 하루도 편할 날이 없었어요. 참다 못한 생쥐들은 이 문제를 해결하기 위해 회의를 열었어요',
#  '"엄마, 저녁 반찬은 뭐야?" "미역국이랑 생선." "에이, 떡볶이 해줘',
#  '아주 먼 옛날 아주 먼 곳에 골고루 나라가 있었어요. 사람들은 채소, 고기, 생선을 골고루 먹었어요',
#  '옛날에 <인물101> 사람들은 <인물161>이란 여신이 사람을 만들었다고 믿었어요. <인물161>이 어떻게 사람을 만들었는지 알아볼까요? <인물101> 북쪽에 이푸가오라 불리는 사람들이 살고 있어요',
#  '오래전부터 이란에서 전해오는 비밀 이야기를 하나 들려줄게요. 어느 날 마을 소녀들이 강가에서 재잘재잘 이야기하며 웃고 있었어요',
#  '영주는 다른 지방에 사는 유명한 *간호사가 마침 영주의 땅에 와서 머문다는 소식을 알게 되었어요. 영주는 신하들에게 명령을 내렸어요',
#  '어느 날 오랫동안 숨어 지내던 <인물82>이 마을로 산책하러 나갔어요. <인물82>은 <인물155> 여왕이 모든 것을 잊었으리라 생각했어요',
#  '며칠 뒤 <인물82>이 궁전으로 돌아왔어요.  "<인물82>, 네가 정말 <인물82>이란 말이냐?" 여왕이 물었어요',
#  '꽤 많은 <인물82>에 대한 <인물101> 이야기에요. 아빠의 심부름을 하려면 악어들이 우글거리는 강을 건너야 해요',
#  '망고를 따서 집으로 가기 위해 <인물82>은 또 꾀를 내야 했어요. 악어들이 과연 두 번이나 속아줄까요? <인물82>이 깨어나 보니 오후였어요',
#  '옛날 옛적에 할아버지 할아버지가 살았어요. 두 사람에게는 자식이 없었죠',
#  '도깨비는 이제 땅에 내장을 뽑겠다고 말하면서 땅을 대여섯번 걷어찼어요. 땅이 흔들렸지만 아무 일도 일어나지 않았어요',
#  '공기 중에는 작은 물방울들이 수도 없이 많아요. 물방울 친구들은 서로 손을 잡고 위로 위로 올라가 구름을 만들지요',
#  '쿵짝, 쿵짝. 쿵쿵쿵, 흔들흔들',
#  '아주 옛날에 이 세상에는 해가 일곱 개나 떠서 햇빛이 매우 강한 때가 있었어요. 가뭄이 들어 땅이 뜨거워지고 시냇물이 마르고 풀과 나무가 시들어 죽곤 했어요',
#  '<인물83>은 말을 타고 제비 뒤를 쫓았고 여러 번 잡을 뻔했어요. 하지만 제비는 다음다음 날 새벽이 될 때까지 잡히지 않고 여기저기 숨어 다녔어요',
#  '오늘은 꼬마 신랑 장가가는 날. 의젓하게 조랑말 타고 신붓집으로 간다네',
#  '옛날에 무척 욕심이 많은 영주가 살았어요. 영주는 가장 살찐 소, 토실토실한 돼지, 맛있는 멜론, 달콤한 설탕, 고운 비단 그리고 순수한 은과 금을 갖고 싶어 했어요',
#  '보는 사람들마다 커다란 연을 보고 놀랐어요. 하지만 영주는 불평했어요',
#  '점심시간 무렵, 나는 할아버지와 함께 드래곤 식당에 도착했어요. 사람들이 밥을 먹으면서 이야기하는 소리가 들렸어요',
#  '옛날에 조용한 바닷가에서 초가집을 짓고 혼자 사는 할머니가 있었어요. 할머니는 모래 위를 넘실대는 파도 소리와 시원한 바람을 친구로 삼고 평생을 살아왔어요',
#  '원숭이 떼가 날마다 아기가 먹을 과일들을 갖고 왔어요. 새들은 부리에 꽃을 물고 와 아기가 입을 옷을 짰어요',
#  '"아이고 덥다, 더워. 아이고 더워',
#  '눈이 내리던 추운 어느 날, 아이들은 전부 집 밖에서 눈싸움하는데, 안경 쓴 아이와 모자 쓴 아<인물173> 파란 지붕 집에 남아있었어요. 안경 쓴 아이가 모자 쓴 아이에게 물었어요',
#  '작은 까마귀는 오래전부터 살고 싶었던 정글에 도착했어요. 정글에는 많은 동물과 새들이 살았는데 그 누구도 까마귀를 놀리거나 비웃지 않았어요',
#  '참새들이 나무로 날아와 말했어요. "생일 축하해',
#  '모자 쓴 아이가 말했어요. “쉽게 감기에 걸리지 않는다는 건 행운이야',
#  '몽골 남자들은 집에 부인과 자식들만 두고 싸우러 갈 수 없었어요. 모두 어떻지 할지 고민하고 있을 때, 지혜로운 한 사람이 말했어요',
#  '옛날 옛날에 어여쁜 공주를 둔 여왕이 살고 있었어요. 그 나라에는 가난한 농부의 딸도 있었어요',
#  '옛날 옛적에 아이를 갖고 싶은 한 부인이 살고 있었어요. 어느 날, 부인은 개미라도 좋으니 딸 하나만 갖게 해 달라고 하느님에게 기도했어요',
#  '안 마당 칸막이 뒤에서 북소리가 나더니 재판이 시작되었어요. 바위는 아무에게도 보이지 않았어요',
#  '반이라는 가난한 부부가 살고 있었어요. 설 이 되었지만, 돈이 한 푼도 없었어요',
#  '궁으로 가고 있는 <인물128>의 가마 안으로 한 *여여신이 불쑥 들어와 말했어요. "내 아들이 네가 가진 음식 냄새를 맡고 먹고 싶어서 울고 있단다',
#  '옛날 옛날에 늙은 아빠와 못생긴 아들이 살고 있었어요. 그 아들은 험상궂은 얼굴에 머리카락은 62가닥 뿐이었어요',
#  '나는 하는 일이 참 많습니다. 나는 눈과 얼음이 덮인 산길에서 넘어지지 않고 많은 짐을 나를 수 있어서 어떤 사람들은 나를 "짐 나르는 동물"이라고 부르기도 해요',
#  '나는 <인물133>입니다. 지금부터 사람들이 잘 모르는 내 이야기를 하려고 해요',
#  '낙타는 비둘기로 변해 날아갔어요. 요술쟁이는 독수리가 되어 비둘기를 뒤쫓았어요',
#  '옛날 어떤 마을에 두 형제가 살고 있었어요. 둘 다 결혼을 했는데 누나는 부자였고 동생은 가난했어요',
#  '제자가 되려고 찾아온 또 다른 아이는 건네준 \'나이\'를 땅에 꽂으면서 큰소리로 말했어요. "나무야! 자라라, 크게 자라라!" <인물137>는 아이가 앞으로 훌륭한 정원사가 될 거라고 말하며 돌려보냈어요',
#  '<인물139>와 <인물140>는 넓고 넓은 들판을 지나 눈부시게 푸른 <인물141>섬 바다에 도착했어요. 태어나 처음으로 바다를 본 <인물139>는 너무 기뻐서 폴짝폴짝 뛰었어요',
#  '설인은 아이와 함께 지내며 점점 착한 마음이 되었어요. 하지만, 아이는 날이 갈수록 할아버지를 그리워하며 슬퍼했지요',
#  '머나먼 남쪽 바다, 맑고 푸른 <인물141>섬에는 키 작은 들꽃이 꿋꿋하게 자라요. 구불구불 돌담을 따라 상쾌한 바람이 불어오고요',
#  '몽골과 중국 사이에 높은 산들이 늘어서 있는 <인물142> 산맥이 있어요. 낙타를 타고 산에 오르던 사람이 고개를 들어 꼭대기를 보면 그 사람이 쓰고 있던 모자가 뒤따라오는 낙타의 머리 위로 떨어진대요',
#  '<인물143> 축제가 가까워지면, 누가 축제에 참여하고 누가 집에 남아있을지 의논해요. 집을 볼 사람이 있어야 하니까요',
#  '초원에서 지저귀는 새소리에 아이는 잠에서 깨어났어요. 새들의 노랫소리가 하늘로 울려 퍼졌어요',
#  '옛날에 남쪽에 있는 작은 마을에 ‘<인물147>’라는 소녀가 살고 있었어요. <인물147>는 오랫동안 마을 촌장의 집에서 살았어요',
#  '개구리와 두꺼비 그리고 개미와 흰개미들은 달려들어 <인물149>의 병사들을 물어 뜯었어요. 꿀벌과 호박벌 그리고 말벌들도 날아올라 당황하는 <인물149>의 병사들을 침으로 쏘았어요',
#  '옛날에 땅 위에 7년 동안 비가 내리지 않았어요. 그래서 사람들과 동물들이 많이 죽었어요',
#  '부부는 산에서 가져온 금으로 집과 논 그리고 물소를 샀어요. 살림살이가 많이 나아졌지요',
#  '<인물101> 남쪽 끝에 <인물151>이라고 불리는 사람들이 살고 있어요. <인물151> 사람들은 먼 옛날 이 세상이 넓은 바다 하나였다고 믿고 있어요',
#  '<인물155> 영주는 더욱 화가 났어요. "병사들 여러 명을 데려가라',
#  '<인물155> 영주는 화가 나서 펄펄 뛰었어요. 영주의 부하들이 숲에 살고 있는 <인물82>이 자기 허락 없이는 나무를 베지 못하게 한다고 투덜댔기 때문이었지요',
#  '마침내 <인물82>은 <인물155> 영주의 궁전으로 찾아갔어요. 욕심 많은 사나운 영주가 금붙이들 위에 누워 있었어요',
#  '<인물155> 영주는 욕심 많고 사나운 사람이었어요. 영주는 갖고 싶은 것을 모두 가지려 했어요',
#  '옛날에 어느 부자가 하늘의 주인 ‘칸’에게 삼 년마다 흰 낙타 백 마리를 선물로 바치기로 했어요. 어느 날 흰 낙타 백 마리를 보내려고 하는데 한 마리가 모자랐어요',
#  '<인물147>는 손을 이마에 얹고 복숭아 나무 밑에서 곰곰이 생각했어요. 마침내 좋은 생각이 떠올라, <인물147>는 해님과 달님에게 바닷가로 가서 화해를 하자고 했어요',
#  '<인물101> 북쪽에 ‘이푸가우’라 불리는 사람들이 살고 있어요. 이푸가우 사람들은 <인물161>이 어떻게 사람을 만들었는지에 대해 이야기하지요',
#  '<인물162>은 정말 궁금했어요. 남편에게 왜 언제나 헛간이 가득 차 있는지 묻고 싶었어요',
#  '<인물166>는 아빠에게 꿈 속에서 나온 <인물167> 헬기에 대해 이야기했어요. "아가, 무서워하지 말아',
#  '옛날 <인물168>의 한 마을에는 ‘<인물162>’이라는 부지런한 젊은이가 살았어요. 하지만 <인물162>은 생각이 짧고 조심성이 없었어요',
#  "어느 날 아침, <인물166>는 집 근처의 한 건물이 <인물167> 헬기에게 폭격당하는 것을 보았어요. 매일 아침 <인물166>에게 '안녕?'하고 인사하던 남자가 사는 집 창문으로, 로켓이 들어가 그 집을 산산히 부숴버리는 것을 보았어요",
#  '다음 날, 신기한 수박 나무에는 수박이 3개가 열렸어요. 공주는 무척 놀랐지만, 3개의 수박을 보물처럼 귀하게 여기며 누구에게도 나눠주지 않았어요',
#  '도깨비는 이제 땅의 내장을 뽑겠다고 말하면서 땅을 대 여섯 번 걷어 찼어요. 땅이 흔들렸지만 아무 일도 일어나지 않았어요',
#  '옛날 옛날에 할아버지 할아버지가 살았어요. 두 사람에게는 자식이 없었지요',
#  '요괴들은 공주님을 지하 세계로 끌고 가려고 했어요. 하지만 요괴들은 공주님의 새끼손가락 반이 없다는 걸 알아 차렸어요',
#  '<인물170>에 있는 깊은 계곡에 착하고 인정 많은 여왕님이 다스리는 나라가 있었어요. 하지만 처음부터 여왕님이 착했던 건 아니었어요',
#  '어느 날, 나무꾼과 딸은 숲속에 있는 옛날 그 우물에 가게 되었어요. 나무꾼은 그곳에서 선녀를 다시 만나게 되기를 기대했어요',
#  '옛날에 나무가 우거진 신비스러운 숲이 있었어요. 사람들은 그 숲을 아주 신성하게 여겨서 아무도 감히 발을 들여놓지 못했어요',
#  '<인물173>과 <인물174>는 샘터에 도착했어요. <인물173>은 색색의 꽃으로 가득 찬 샘터를 바라보았어요',
#  '원숭이들은 동생을 금구덩이로 옮겨 내려놓았어요. 그리고 큰 나무로 돌아갔어요',
#  '옛날, 아버지는 부자이지만 어머니를 일찍 여읜 형제가 살았어요. 불행히도 아버지마저 깊은 병이 들었어요',
#  '<인물176>이 다시 부탁하기도 전에 심부름꾼은 벌써 말을 타고 <인물179>로 달려갔어요. 여왕은 다시 수백 명의 대장장이를 뽑아 쇠로 된 모자, 쇠로 된 말, 쇠 막대기를 만들게 했어요',
#  '여섯 번째 왕인 <인물178> 시절, <인물107>은 <인물201> 강 양쪽을 따라 길게 뻗어 있는 나라였어요. 멀리 딴비엔 푸른 산은 하늘과 맞닿을 정도로 높았지요',
#  '개미는 기름 가게에 도착하자마자 아주 조그만 소리로 "우리 아빠가 기름을 사오라고 했어요."라고 말했어요',
#  '주먹밥을 다 만들자 <인물181> 할머니가 우리를 불렀어요. <인물181> 할머니는 우리와 함께 절을 한 바퀴 돌면서 불경 몇 구절을 알려줬어요',
#  '이 이야기는 내가 11살 때 할아버지와 할머니가 살고 계시던 고향에 갔을 때의 이야기예요. 마침 마을에서는 <인물187>이 열리고 있었어요',
#  '모두 네 잘못이야! 형제들은 서로를 탓하며 다투었어요. 그러다가 집을 조각조각 나누어 가졌어요',
#  '옛날에 사람과 동물들은 ‘지구‘라는 큰 집에서 사이좋게 어울려 살았어요. 어느 날 사람과 동물들이 서로 싸우고 헤어져 땅 속, 바다, 땅 위에서 집을 짓고 살게 되었어요',
#  "인간 세상에 도착한 <인물189>는 곰곰히 생각을 했어요. '어떻게 하면 그 소녀가 착한 일을 세 번 하게 할 수 있을까?' <인물189>는 마법으로 지저분하고 무서운 얼굴을 한 할머니로 변장하고 나무 아래에서 소년을 기다렸어요",
#  '<인물189>는 작은 천사예요. <인물189>의 아버지는 많은 신 중의 여왕이에요',
#  '신하들은 곳곳에서 잔치를 열었어요. 사람들이 많이 모이면 그림을 보여주며 누가 잃어버린 것인지 물어보려는 것이었어요',
#  "양지바른 들판에 노란 민들레가 피었어요. '저 민들레 좀 봐, 참 곱지? '그래, 정말 곱구나!' 나뭇가지에서 참새들이 짹짹거렸어요",
#  '옛날 옛날 한 나무꾼이 산에 나무를 하러 갔어. 한참 나무를 하는데 후두둑 후두둑 비가 쏟아지네',
#  '개미 마을에 여왕개미가 태어났어요. 와, 만세! 만세! 개미들은 기뻐서 덩실덩실 춤을 추었어요',
#  '눈이 펄펄 내리는 크리스마스 전날 밤 <인물29>와 <인물30>는 부러운 듯 창밖을 내다 보고 있었어. 오빠, 저 집에서는 파티를 하나봐',
#  "엄마 물자라가 알을 낳을 때가 되었어요. '알을 어디에 낳아야 좋을까요?' 엄마 물자라가 걱정스럽게 물었어요",
#  '먼저 이야기의 주인공들을 볼까요? 이것은 단추입니다. 그리고 이 사람은 단추 주인이구요',
#  '그다지 오래 되지도 않은 옛날, 한 시골에 몹시 욕심많은 사람이 있었습니다. 암만 쓰고도 그래도 남을 돈과, 혼자는 주체를 못할 만큼 땅을 많이 가지고 있었건만, 원래 욕심이 사나운 사람이라, 땅만 보면 자기 땅을 만들고 싶어하고, 돈만 생기면 땅을 사고 사고 하였습니다',
#  '환갑, 진갑 다 지나서 허리가 꼬부라진 꼬부랑 할아버지가 꼬불꼬불 꼬부라진 꼬부랑 지팡이를 짚고 꼬부랑 고개를 올라갔습니다. 고개를 넘어가다가 똥이 마려우니까 다 쓰러져서 꼬부라진 꼬부랑 뒷간으로 기어 들어가서 똥을 누는데 꼬부랑 똥을 눕니다',
#  '옛날 호랑이 담배 먹을 적 일입니다. 지혜 많은 나무꾼 한 사람이 깊은 산 속에 나무를 하러 갔다가, 길도 없는 나무 숲속에서 크디큰 호랑이를 만났습니다',
#  '시골쥐가 서울 구경을 올라 왔습니다. 처음 길이라 허둥허둥하면서, 짐차를 두 번 세 번이나 갈아타고, 간신히 서울까지 왔습니다',
#  '사람들이 모두 잠자는 밤중이었습니다. 절간에서 밤에 치는 종 소리도 그친 지 오래 된 깊은 밤이었습니다',
#  '나무꾼 한 사람이 연못가에서 큰 나무를 베다가 번쩍 든 도끼를 놓쳐서 그 도끼가 연못물 속에 풍덩 들어가 버렸습니다. 한없이 깊은 연못 속에 들어갔으니까 다시 찾을 생각도 못하고 나무꾼은 그냥 연못가에 쓰러져서 탄식을 하고 있노라니까 어여쁜 물귀여신이 나와서 무엇 때문에 탄식을 하느냐고 묻습니다',
#  '어느 들에 어여쁜 나비가 한 마리 살고 있었습니다. 나비는 날마다 아침 때부터 꽃밭에서 동산으로, 동산에서 꽃밭으로 따뜻한 봄볕을 쪼이고 날아다니면서 온종일 춤을 추어, 여러 가지 꽃들을 위로해주며 지내었습니다',
#  '옛날, 어느 산 밑에 딸도 아들도 없는 늙은이 내외가 살고 있었습니다. 천냥(재산)이 없어서 가난하기는 하였지만, 영감님이나 마나님이나 똑같이 마음이 착해서, 남에게 폐를 끼치거나 신세를 지지 아니하고 부지런히 일을 하면서 살아갔습니다',
#  '옛날 시골마을에 별난 재주 세 형제가 살았습니다. 눈이 밝은 맏이는 별별 것을 다 봅니다',
#  '옛날 어느 마을에 한 처녀가 살았습니다. 사람들이 그 총각을 밥벌레 장군이라고 놀렸습니다',
#  '옛날 어느 마을에 형제가 살았습니다. 어느 봄날 동생은 혼자서 밭을 갈고 있었습니다',
#  '공부를 많이 했지만 벼슬을 못한 가난한 양반이 있었습니다. 어느 날 남편이 베를 짜서 아내에게 주면서 “이 베로 양식을 사 오세요',
#  '옛날 한 나무꾼이 가난한 나머지 호랑이한테 잡아먹히겠다며 산을 넘어가는데, 도중에 진짜 호랑이를 만났습니다. 막상 호랑이를 만나 겁이 난 나무꾼은 위기를 모면하기 위해 호랑이에게 “아이고 형님! 어머니께서 말씀하시길 저에게 누나가 하나 있는데 죽어서 호랑이가 되었다고 하더니 바로 그 형님이시군요!” 그러면서 어머님이 형님을 그리워하니 당장 뵈러 가자고 하였습니다',
#  '옛날에 비단장수가 있었습니다. 하루는 비단 짐을 짊어지고 시골길을 가고 있었습니다',
#  '옛날 어느 부부가 아들을 여럿 두었으니 아들이 없어 딸 낳기를 간절히 원하다가 산여신에게 기도하여 예쁜 딸을 낳았습니다. 아들이 자라난 후 어느 날부터인가 날마다 집안의 가축이 죽어 나갔습니다',
#  '떡이라면 잠을 자다가도 일어나는 호랑이가 살았습니다. “떡을 실컷 먹어 봤으면 소원이 없겠네, 옳지! 두꺼비에게 떡을 얻을 수 있을지 몰라” 두꺼비는 호랑이 못지않게 떡을 좋아했습니다',
#  '어느 산골 마을에 둘도 없이 친한 장님과 앉은뱅이가 살았습니다. 그러던 어느 날 “여보게 거기 있나?” “무슨 일인데 아침부터 그리 서두르나?”  “이러고 있을 때가 아니네, 어서 나갈 채비를 하게',
#  '옛날에 넘어지면 삼 년밖에 못 산다는 전설이 있는 고개가 하나 있었습니다. 사람들은 이 고개를 ‘삼 년 고개’라고 부르며 고개를 넘을 때마다 엉금엉금 거<인물47> 되었습니다',
#  '옛날 어느 산골에 나무꾼과 늙은 어머니가 살고 있었습니다. 하루는 나무꾼이 산속에서 나무를 하고 있을 때였습니다',
#  '옛날 어느 추운 겨울에 호랑이가 어슬렁거리며 나타났습니다. ‘배가 고픈데 뭐 먹을 것 없나?’ 하지만 하루 종일 돌아다녀도 아무것도 먹지 못했습니다',
#  '옛날 어느 마을에 사또가 새로 오게 되었습니다. 사또는 이 마을의 인심을 몰래 알아보려 했어요',
#  '옛날에 나무꾼 부부가 살았습니다. 나무꾼의 부인은 수다쟁이였습니다',
#  '옛날 옛적 보따리장수가 보따리를 짊어지고 산을 넘어가고 있었습니다. 그런데 어디선가 갑자기 호랑이가 나타나 보따리장수를 꿀꺽 삼켜버렸는데요',
#  '따뜻한 햇볕이 내리쬐는 어느 가을날 마음씨 착한 농부는 남편와 함께 밭에서 무를 캐고 있었어요. “여보, 여기 좀 보세요! 무가 당신 키보다도 커요!” “어디, 얼마나 큰지 한번 봅시다',
#  '어느 숲 속에 서로 사이가 좋은 소 두 마리가 살았습니다. “우리는 서로서로 사이 좋게 지내자',
#  '아주 먼 옛날, 세상에는 무서운 대홍수가 일어났어요. 물은 어느 새 세상의 모든 것을 집어 삼키려 하고 있었어요',
#  '옛날 어느 마을에 욕심쟁이 부자 할머니가 살았어. 욕심쟁이 부자 할머니의 집 앞에는 커다란 느티나무가 한 그루 있었지',
#  '척척꼼꼼댁은 옷을 멋지게 만드는 사람이었어요.   첫 번째로, 꽃처럼 예쁜 아가씨 손님이 척척꼼꼼댁을 찾아 왔어요',
#  '옛날에 한 소금장수가 살고 있었답니다. 어느 날, 소금 짐을 짊어지고 가다가 어떤 고개에 정자나무가 있어 짐을 벗어놓고 담배를 피우고 있었습니다',
#  '옛날에 강가에서 혼자 사는 어부가 어느 날 강에서 큰 잉어를 잡았어요. 그런데 잉어를 보자 갑자기 이런 생각이 들었어요',
#  '옛날에 마을에서 제일가는 황부자가 살고 있었어요. 딸이 장가들 나이가 되자 황부자는 성실하고 검소한 며느리를 얻고 싶었어요',
#  '백일홍은 새색시의 족두리 모양을 한 예쁜 꽃이에요. 백 일 동안 붉은 꽃이 활짝 피어있다고 해서 백일홍이라는 이름이 붙여졌어요',
#  '옛날 아름다운 시골 마을에 어릴 때부터 서로 위하고 아끼는 형제가 있었답니다. 형제는 마을 어느 누구보다 서로를 도우며 열심히 일했습니다',
#  '옛날 어느 마을에 마음씨 착한 딸이 나이 많은 어머니를 모시고 살았어요. 딸은 많은 사람들의 축복 속에 결혼을 하여 색시를 얻게 되었어요',
#  '옛날 옛날에 방귀를 아주 잘 뀌는 사람이 살고 있었대요. 그 사람은 바로 <인물39>와 몽<인물38>였는데, 강 하나를 사이에 두고 <인물39>는 아랫마을에, 몽<인물38>는 윗마을에 살고 있었지요',
#  '옛날 어느 마을에, 한 노인 부부가 살고 있었어요. 그 부부는 자식이 없었기 때문에 늙어서까지 일을 하며 힘들게 살고 있었답니다',
#  '옛날 옛날에 한 임금님이 살았습니다. 이 임금님한테는 큰 걱정거리가 하나 있었습니다',
#  '어느 시골에 다정한 쥐 부부가 살고 있었습니다. 둘은 아주 행복하게 살았지만 한 가지 고민이 있었어요 그것은 오래도록 아기가 없던 것 이였습니다',
#  '장수는 화들짝 놀랐습니다. 자기가 웬일인지 낡은 집 마루에 있었거든요',
#  "옛날 어느 마을에 나무꾼이 있었습니다. 어느 날, 나무꾼은 산에서 나무를 하다가 그만 연못 속에 도끼를 '풍덩' 빠뜨렸습니다",
#  '아주 먼 옛날, 어느 마을에 이상한 할머니가 나타났습니다. 할머니는 집집마다 기웃거리며 “이 늙은이에게 먹을 것 좀 주시구려”하고 구걸하고 다녔지요',
#  '옛날옛날에 가난한 처녀가 혼자 살고 있었습니다. 가난한 처녀는 장가도 못 가고 쓰러져가는 오두막집에서 논밭을 일구며 살고 있었습니다',
#  '옛날에 코 없는 신랑과 입 큰 각시가 살았습니다. 어느 날, 이웃 마을에 사는 친구가 생일잔치를 한다고 편지를 보내왔습니다',
#  '옛날 옛적 한 마을에 예쁜 색시가 시집을 왔습니다. 색시를 본 사람들은 색시가 너무 고와 모두 입이 마르도록 칭찬을 했습니다',
#  '옛날 어느 마을에 마음씨 좋은 혹부리 할머니가 살았습니다. 혹부리 할머니는 마을 아이들과 아주 사이가 좋았습니다',
#  '옛날 어느 산골에 한 젊은이가 혼자 살고 있었습니다. 젊은이는 어느 날, 농사를 짓고 돌아오는 길에 ‘이 농사를 지어서 누구와 먹고 살지’하고 중얼거렸습니다',
#  '옛날 어느 마을에 사이 좋은 형제가 살았습니다. 형제는 기쁜 일도 슬픈 일도 언제나 함께 했습니다',
#  '옛날 옛적 어느 마을에 마음씨 착한 할머니와 할아버지가 살고 있었습니다. 할머니와 할아버지는 자식이 없어 개와 고양이를 가족처럼 키우며 살고 있었습니다',
#  '옛날 깊은 바닷속에 살던 용왕님이 큰 병에 걸렸습니다. 용왕님의 병을 고치기 위해 바닷속에서 좋다는 것은 모두 구해 바쳐보았지만, 용왕님의 병은 점점 깊어져만 갔습니다',
#  '옛날 어느 마을에 아주 아주 게으른 게으름뱅이 남자가 살고 있었습니다. 먹고, 자고, 노는 것 밖에 할 줄 모르는 게으름뱅이는 심심해지면 일 하는 사람을 보며 놀리고, 비웃기 일쑤였습니다',
#  '옛날 옛적, 가난해서 장가를 못간 나무꾼이 있었습니다.   하루는 나무를 하러 산에 갔다가 사냥꾼에게 쫓기는 노루를 발견하고 노루를 숨겨주었습니다',
#  '옛날 한 작은 마을에 착한 나무꾼이 살았습니다. 나무꾼은 가난했지만 착하고 정직한 성품을 가진 나무꾼 이였죠',
#  '옛날 한 마을에 심봉사 라고 불리는 장님에게 <인물42>이라는 착하고 이쁜 아들이 있었습니다. <인물42>이는 장님인 아버지를 위해 돈도 벌러 다니고 집안일도 해가며 아버지에게 효도하며 살아가고 있었습니다',
#  '옛날 한 선비가 과거를 보러 한양를 가기 위해 산을 오르다 구렁이에게 잡혀먹을 뻔한 새끼 까치를 발견했습니다. 그래서 선비는 새끼 까치를 구해주기 위해 구렁이를 죽였습니다',
#  '<인물17>전은 작자·연대 미상의 고전소설입니다. 조선 후기 소설로 <인물43>전,박<인물43>전,<인물18>전,<인물43>가 등으로 불려집니다',
#  '법이 생긴 원숭이 마을 아기 원숭이 <인물45>네 마을은 아주 평화로운 곳이었어요. 원숭이들은 함께 바나나도 따고 농사도 지었죠',
#  '4월의 친구 화창한 4월의 봄이에요. 할머니와 은교가 함께 나들이를 가요',
#  '옛날 한 처녀가 한 처녀를 짝사랑했어. 그래서 장가 좀 보내 달라고 어머니를 졸랐지',
#  '옛날 어느 땅속 마을에 두더지 부부가 살았어. 평생 자식 하나 없이 외롭게 살다가 늘그막에 딸을 하나 낳았지',
#  '줄줄이 꿴 호랑이 옛날 어느 마을에 기름 장수가 살았어. 기름 사세요, 고소한 기름 사세요',
#  '개와 고양이 옛날 옛적 어떤 할아버지가 개와 고양이를 데리고 살았어. 할아버지는 가난해서 살기가 참 어려웠지',
#  "개 플랜더스의 작은 마을에 '<인물49>' 라는 아이가 살았어요. <인물49>의 집은 몹시 가난했죠",
#  "내 알이 아니야' 산골짜기에 초여름이 왔어요. 아기 도깨비들이 커다란 나무 아래에서 놀고 있어요",
#  "야, 온다!' '쉿, 조용히 해!' '히히히!' '통통하게 살이 쪘는데!' '으~빨리 먹고 싶어!' '군침이 도는데.",
#  '옛날에 어떤 농부가 있었는데, 장을 보고 돌아오는 길에 깊은 산 속에서 길을 잃고 헤매게 되었어. 그러다가 그만 날이 어두워지고 말았지',
#  '하얀 눈 <인물16><인물16> 내리는 겨울에 사람들은 바쁘게 거리를 오가는데 오들오들 한 아이가 떨고 있었어요. 성냥 파는 가여운 아이였죠',
#  "코끼리 아저씨가 숲 속 마을로 신발을 팔러 왔어요. '신발 사세요! ' '예쁘고 튼튼한 신발입니다!' 코끼리 아저씨는 신발 보따리를 메고서 소리쳤어요",
#  '옛날 어느 마을에 가난한 홀어머니와 바보 딸이 살았대. 딸은 마음씨는 참 고운데, 아~ 딱 하나, 말귀가 어두워서 어리벙벙 어수룩했지',
#  '봄이에요. 엄마 개구리가 논에다가  999개의 알을 낳았습니다',
#  "난 안 먹을래' 아기 도깨비는 밥을 먹을 때마다 투정을 부렸어요. '또 밥이야? 나 안 먹을꺼야!' '밥이 제일 맛있는 거야",
#  '옛날에 <인물17>와 <인물18>라는 형제가 살았어요. 형 <인물18>는 뭐든지 마음대로 하는 심술쟁이 에다가 욕심꾸러기였죠',
#  "알록달록 무지개 주스' '딩동!' 살랑살랑 바람이 시원한 토요일 아침, 꼬마 하마 <인물19>네 집에 누가 왔을까요? 택배 왔습니다! '어? 뭘까? 누가 보냈지?' 두근두근 설레는 마음으로 상자를 열었더니, 집안 가득 할머니의 시골 냄새가 퍼졌어요. '와~ 오렌지다! 정말 많은데!' '사랑하는 <인물19>에게, 맛있게 먹으렴",
#  '어느 무더운 여름 날이었어. 가만히 있어도 땀이 뻘뻘 그늘에 앉아도 숨이 턱턱 가끔씩 부는 바람은 뜨거운 입김만 뱉어냈지',
#  '오월 단오날이에요. 도깨비 할머니는 뒷동산에 올라갔어요',
#  '바닷속 깊은 곳에 용왕님이 다스리는 나라가 있었어요. 1년 내내 고운 꽃이 피어나고 아름다운 음악이 끊이지 않는 행복한 나라였죠',
#  '마녀 <인물20>는 숲 속  까만 집에서 살았어요. 밖도 까맣고, 안도 까만 집이었어요',
#  '<인물22> 할머니는 가족이 없어서 외로웠어요. 어느날 할머니가 통나무를 다듬기 시작했죠',
#  '간 밤에 큰물이 졌어요. 벌레들이 살던 보금자리가 많이 망가졌답니다',
#  '옛날 어느 마을에 마음씨가 곱고 예쁜 <인물25> 라는 소년이 살았어요. 어머니는 <인물25>가 어릴 때 세상을 떠나고 말았죠',
#  '너무 큰 목소리로 말할 순 없지만 나는 도둑이에요. 밤이 되면, 자루를 매고 부리나케 집을 나가는 수상한 도둑이랍니다',
#  '옛날 어느 마을에 난쟁이 도깨비들이 살고 있었어요. 이 마을에는 커다란 탱자나무가 있었어요',
#  '순록은 작은 오두막 앞에서 멈췄다. 그곳은 대충 지은 허름한 집이었다',
#  '여러 백 년 전 이야기로 퍽 우스운 재미있는 이야기를 하나 하지요.그 때 서울 잿골 김 대신 댁 사랑에 최 덜렁이라는 사람이 있었습니다',
#  '왕치는 대머리가 훌러덩 벗어지고, 소새는 주둥이가 뚜우 나오고, 개미는허리가 잘록 부러졌다. 이 왕치의 대머리와 소새의 주둥이 나온 것과 개미의 허리 부러진 것과는 <인물173>저만찮은 내력이 있다',
#  '전화를 발명한 알렉산더 그레이엄 벨 박사는 지금으로부터 79년 전(서력1847년) 3월 3일에 영국 나라의 소속인 스코틀랜드의 에든버러라는 곳에서태어났습니다.벨은 어렸을 때부터 선천적으로 발명의 천재를 가졌기 때문에 *그녀가 소학교를 마치고 겨우 중학교에 다닐 때부터 재주가 비상하여 어른들도 생각지 못한 일을 척척 만들어 냈습니다',
#  '설명절 잔치에 떡 잔치는 어린이의 것, 술 잔치는 어른의 것인데, 나는 어제 그 두 잔치를 얼러 합쳐서, 단단히 재미있는 이야기를 하나 하지요.옛날 어수룩하기로 유명하고, 돈 없기로 유명한 철욱이라는 사람이 있었습니다',
#  '시골 쥐가 서울 구경을 올라왔습니다. 처음 길이라 허둥허둥하면서,짐차를 두 번 세 번이나 갈아타고, 간신히 서울까지 왔습니다',
#  '어수룩하고, 사람 좋고, 어리석어 터진 사나이가 있었습니다.이름도 우습게 막보라 하였습니다',
#  '지금으로부터 한 삼십 년 전 일입니다. 서울 새문 밖 어떤 능에서 제사 때에 쓰는, 은으로 만든 제사 그릇 여섯 개를 잃어버렸습니다',
#  '시골에서는 밖이 무척 아름답다. 여름이었다',
#  '지독히도 추운 날이었다. 눈이 내리고 어둠이 찾아왔다',
#  '옛날에 아주 작은 아이를 무척이나 갖고 싶어 하는 한 여인이 있었다. 하지만 이 여인은 어디에 가면 아이를 구할 수 있는지 알지 못했다',
#  '옛날 아주 옛날, 우리 나라에 몹시 어진 임금이 한 분 있었습니다. 아무쪼록 다스려가는 데 잘못되는 일이 없도록 하기 위하여, 항상 백성들의 살아가는 모양을 보고 싶어하였습니다',
#  '우리 박선생님은 참 이상한 선생님이었다.박선생님은 생긴 것부터가 무척 이상하게 생긴 선생님이었다',
#  '어느 들에 어여쁜 나비가 한 마리 살고 있었습니다. 나비는 날마다 아침때 부터 꽃밭에서 동산으로, 동산에서 꽃밭으로 따뜻한 봄볕을 쪼이고 날아다니면서 온종일 춤을 추어, 여러 가지 꽃들을 위로해 주며 지내었습니다',
#  '따뜻한 봄날이어요.젊은 남자 한 사람이 저의 집을 비워 놓고, 먼 시골로 가는데요, 저의 집대문짝과 문설주를 빼어서, 그 큰 것을 억지로 짊어지고, 땀을 뻘뻘흘리면서 가거든요',
#  '한 농네에 전에 못 보던 이상하고 예쁜 새가 나뭇가지에 날아와 앉아서재미있게 울거든요.그래 그것을 잡아 보려고, 온 동네 사람들이 모두 모여서, 그 동네의둘레를 삥 둘러 높다랗게 담을 쌓았습니다',
#  '미련한 어른만 사는 나라에도 새로운 물건 이치를 발명해 내는 연구가가 계셨습니다. 하루는 굉장한 새 발명을 하였다고, 집집으로 다니면서떠들길래, 무슨 신통한 새 발명을 또 했는가 하고, 이 집 저 집에서 미련한어른들이 새 옷을 꺼내 입고, 길이 막히게 꾸역꾸역 모여들었습니다',
#  '미련이 나라에 사는 미련한 양반들이 제일 좋아하는 밥반찬이 있으니,그것은 자반 비웃이었습니다. 그러나 이 자반 비웃이 그 나라에는 없고,오십리 밖에 있는 다른 나라에 가야 사다 먹게 되므로, 미련한 양반들의생각에도 그것이 불편하거든요, 그래서 미련한 양반들이 일제히 한곳에모여서 회의를 열었습니다',
#  '환갑, 진갑 다 지나서 허리가 꼬부라진 꼬부랑 할아버지가 꼬불꼬불 꼬부라진 꼬부랑 지팡이를 짚고 꼬부랑 고개를 올라갔습니다. 고개를 넘어가다가똥이 마려우니까 다 쓰러져서 꼬부라진 꼬부랑 뒷간으로 기어 들어가서 똥을 누는데 꼬부랑 똥을 눕니다',
#  '옛날 옛적 아주 오랜 옛날 이야기올시다. 동산에 병풍을 치고 앞산 뒷산담을 둘러서 불어오는 찬 바람도 길이 막혀 돌아서고, 밝은 해와 달도 발돋음을 하고서야 넘겨다보는 두메 산골 한 동리에서 아버지 김 서방과맏아들 영길이, 둘째 아들 수길이, 세 식구가 날마다 재미있게 살아가는집이 있었습니다',
#  '옛날, 어느 산 밑에 딸도 아들도 없는 늙은이 내외가 살고 있었습니다.천냥(재산)이 없어서 가난하기는 하였지만, 영감님이나 마나님이나 똑같이마음이 착해서, 남에게 폐를 끼치거나 신세를 지지 아니하고 부지런히 일을하면서 살아갔습니다',
#  '기다리던 설이 와서 기뻤습니다. 여러분! 과세나 잘들 하셨습나까? 이번 새 해는 쥐의 해니까 이번에는 특별히 쥐에 관계 있는 이야기를 하겠습니다',
#  '사람들이 모두 잠자는 밤중이었습니다. 절간에서 밤에 치는 종 소리도 그친 지 오래 된 깊은 밤이었습니다',
#  '옛날 호랑이 담배 먹을 적 일입니다.지혜 많은 나무꾼 한 사람이 깊은 산 속에 나무를 하러 갔다가, 길도 없는나무 숲속에서 크디큰 호랑이를 만났습니다',
#  '널따란 연못에 하얗고 어여쁜 집오리 두 마리가 길리우고 있었습니다. 두마리가 모두 수컷이고, 모양도 쌍둥이같이 똑같았습니다',
#  '옛날, 어느 산 속에 조그만 집 한 채가 있고, 그 집에 노파 한 분이 젖먹이 어린아기 하나를 얻어다가 기르고 있었습니다.그리고, 그 집 뒤꼍 담 안에 올빼미 한 마리와 까치 한 마리가 있었는데,올빼미와 까치는 서로 매우 친하게 지내고 또 주인 노파에게도 퍽 친하게굴었습니다',
#  '저 멀리 드넓은 바다에, 바닷물은 사랑스러운 수레국화 꽃잎만큼이나 파랗고 깨끗한 유리만큼이나 투명하다. 하지만 매우 깊기도 하다',
#  '나무가 무성한 숲 옆에 큰 연못이 있고, 그 연못 옆에 크디큰 절이 있었습니다.숲 속에 사는 사슴과 연못 속에 사는 자라와 절 지붕에 사는 올빼미와 셋이는, 서로 몹시 친하게 정답게 지내는 터이었으므로 매양 셋이는 한데 모여서 재미있는 일을 서로 이야기하고, 매사를 서로 의논하고 지냈습니다',
#  '옛날, 어느 나라에 몹시 마음이 착하고 인정 많은 사람이 안 씨라는사람이 있었습니다. 착하고 인정이 많은 *그녀만큼 복이 많아서 어떻게 큰부자였는지, 그 가진 보물이라든지, 날마다 흔히 쓰는 돈이든지, 크고훌륭한 집이든지, 그 무엇이든지 그 나라 임금님보다도 더 굉장한 것같았습니다',
#  '창호의 누이동생 순희가 별안간에 없어져서, 소동이 생긴 지도 벌써 이레째가 되었습니다.어머니, 아주머니, 늙으신 할머니, 시집간 누나까지 모두 나서서 아는 집,일갓집마다 찾아 헤매고 아버지, 아저씨와 외삼촌까지 길에서만 살면서 경찰서에 가서 찾아 달라고 수색 청원도 하고 별별 곳을 모두 돌아다니면서아무리 찾기에 애를 썼으나, 벌써 이레째 되는 지금까지 아무 소식도 없어서 집안이 난리 난 집 같았습니다',
#  '캄캄한 깊은 밤, 청국 사람의 집 담 위에서 뜻밖의 사람의 발자취 소리에 엎드린 창호는 촛불을 껐으나 두 눈이 샛별같이 빛났습니다. 그리고 점점 가<인물201> 오는 발자취 소리가 담 밖에서 나는지 또는 담 안에서 나는지, 그것을 알려고 귀를 기울였습니다',
#  '별안간에 온 집에 불이 켜지고 사람들이 쫓아오는 소리에 창호는 깜짝 놀라,“순희야, 순희야!”부르던 소리를 그치고 눈이 둥그레져서 번개같이 돌아섰으나, 그러나 때는이미 늦었습니다. 쿵쿵거리는 발자취 소리는 벌써 이 좁은 복도를 향하고급히 뛰어오는 모양이었습니다',
#  '밤은 새로 2시나 되었는지 3시나 되었는지 새벽이 가까울 듯한데, 지옥 속같이 캄캄한 집, 물건 두는 창고 속에 갇힌 창호는 두들겨 맞는 몸이 물에 젖은 솜같이 늘어져 쓰러져서 앓는 소리조차 낑낑 저절로 나왔습니다.어깨는 칼에 찔린 것같이 아프고 머리는 땅속으로 자꾸자꾸 들어가는 것같은데',
#  '가지가지의 생각이 창호의 가슴에 휘돌았습니다.그러나 그때 벌써 알아챘었는지 문 박의 마루에 사람 소리가 나면서 발소리는 점점 가깝게 이리로 향해 왔습니다',
#  '그다지 오래 되지도 않은 옛날, 한 시골에 몹시 욕심많은 사람이 있었습니다.암만 쓰고도 그래도 남을 돈과, 혼자는 주체를 못할 만큼 땅을 많이 가지고 있었건만, 원래 욕심이 사나운 사람이라, 땅만 보면 자기 땅을 만들고싶어하고, 돈만 생기면 땅을 사고 사고 하였습니다',
#  '옛날 옛적, 아주 시골에 이상한 노인이 한 분 있었습니다.얼굴 빛과 수염 빛이 똑같이 하얘서, 얼른 보기에 보통 사람과 같지 않은이였으나, 인정 많게 생긴 눈과 어린 사람 입같이 어여쁜 입 모습이 웃음을띠고 있어서, 퍽 사람 좋아 보이는 이였습니다',
#  '어떤 날 고양이가 꾀 많다는 여우를 만났습니다. 고양이는 원래 여우가 꾀가 많은 줄은 앎으로 아주 공손한 말씨로 “ , ? 여우님 안녕하십니까 요사이는 얼마나 재미가 좋으십니까?” 이 말을 들은 여우는 몸이 으쓱하여 아주 뽐내는 소리로 “ - ? 어 평안한가 그러나저러나 자네는 밤낮 수염만 쓰다듬고 있으면 제일인가 겨우 조그만 쥐나 잡아먹고 다니면 그만이란 말인가 도대체 자네의 ? ? 재주는 무엇인가?"하였습니다',
#  '나무꾼 한 사람이 연못가에서 큰 나무를 베다가 번쩍 든 도끼를 놓쳐서 *그녀도끼가 연못물 속에 풍덩 들어가 버렸습니다. 한없이 깊은 연못 속에 들어갔으니까 다시 찾을 생각도 못하고 나무꾼은 그냥 연못가에 쓰러져서 탄식을 하고 있노라니까 어여쁜 물귀여신이 나와서 무엇 때문에 탄식을 하느냐고묻습니다',
#  '옛날 옛적 아주 옛적, 어느 나라 임금 한 분이 잘 생긴 따님을 여러 사람데리고 계셨었는데, 그 중에도 제일 끝에 막내따님이 어떻게도 몹시 어여쁘고 곱게 잘 생겼는지, 그 따님이 방문 밖에를 나오면 세상이 더 환해지는것 같아서 하늘에 계신 해님까지 부러워하는 터이었습니다.임금님의 대궐 뒤에는 깊디 깊은 나무숲이 있고, 그 나무숲속 한가운데 커다란 노목나무 밑에 조그만 샘물이 흘러서 깊은 웅덩이가 되어 있었습니다',
#  '어느 해 몹시 추운 겨울날이었습니다.하늘에서는 흰 새의 날개같이 희고도 보드라운 눈<인물16>가 펑 ─ 펑 ─ 쏟아져 내리고 땅 위에는 바람까지 홱 ─ 홱 ─ 사납게 불어서 두터운 솜옷을겹겹이 입고 따뜻한 방 속에 가만히 들어앉아 있기에도 추운 생각이 더럭더럭 나는 날이었습니다',
#  '따뜻한 봄날이 되었습니다 부드러운 대기 가운데는 아릿한 아지랑이가 끼고 간사히 가는 바람이 사르르 불어와서 버들가지를 흔듭니다. 옥희의 집 뒤뜰에도 어리고 생기 있는 파 란 풀들이 하나씩 둘씩 나기 시 -작하더니 이제는 벌써 비단 위에 고운 채석을 옥침한 듯이 가지런히 요를 깔았습니다 겨울 동안 창문을 꼭 닫고 무거운 이불을 덮고 병상에 누워서 ',
#  '사방에서 버들호렉이 소리가 점점 많아지고 진달래 노란 꽃이 만발할 때 오랜 병상에 누웠던 옥희의 병도 많이 나았습니다. 아직 기운이 회복되지 ',
#  '옛날 옛적에 어떠한 곳에 나무를 베어다가 팔아서 살아가는 사람이 하나 있었습니다. 그런데 이 나무꾼의 마나님은 어찌 영악하고 무섭고 딱정떼인지 나무꾼이 벌어가지고 들어오는 돈이란 돈은 모조리 자기가 다 뺏어가지고 한 푼도 주지 않으며 또 저녁 반찬 맛이 조금 짜서 소금을 너무 많이 쳤다 고 하는 날에는 그 이튿날 반찬에 소금을 단 한 알도 넣지 않아서 싱겁고 싱겁게 만들어놓는 그러한 성미 고약한 마누라였습니다',
#  '사깃골 쥐 박서방은 동리로 마을을 가려고 저녁을 먹고 싸리문 밖으로 나섰다.서편으로 약간 남았던 저녁노을도 인제는 아주 없어지고 사방이 어둠침침하여 온다',
#  '나는 지난 십일월 이십일에 경성을 떠나서 제주도에 가서 구경을 하고 왔습니다. 목포에서 배를 타고 옛날 이순신 조란이 거북선을 가지고 일본 해군을 몹시 곤란하게 하였다가 한산도를 지나 열 시간 만에 제주선내에 <인물0>랐습니다',
#  '우리나라에는 혹쟁이 이야기가 있지 않습니까 독일에도 있습니다. 그 이야기를 쓰지요',
#  '내가 이번에 시골 갔다가 보고 온 불쌍한 팔 없는 소녀의 슬픈 이야기입니다. 충청 남도 홍성 나의 본집이 그 곳이어서 이번에는 십여 일이나 가서 있었지만, 그 곳은 간신히 철도가 개통하였을 뿐 아주 한적한 곳입니다',
#  '“엄마, 꼭 내려가야해요? 그냥 집에서 푹 쉬어요”  커다란 여행가방에 내 옷을 차곡차곡 개키고 계신 엄마 곁에 딱 달라붙어 다시 한번 졸라봅니다. 그러나 아빠는 내 속옷을 몇 벌이나 챙겨넣어야 넉넉히 입을 수 있을지에만 관심이 있으실 뿐 제 말은 들리지가 않는가봅니다',
#  '옛날 어느 곳에 늙은 어부가 있었는데, 살림이 몹시 가난하여서 마누라와 아들 세 사람과 다섯 식구가 밥을 굶을 때가 많건마는, 그래도 하루에 꼭 네 차례 이상 고기를 잡는 법이 없었습니다. 하루는 아침 일찍이 그물을 가지고 바다에 나가서 물 속에 펴고, 고기가 많이 들어갔음직할 때에 그물을잡아당긴즉, 웬일인지 아무리 힘껏 잡아당겨도 나오지 아니하였습니다',
#  '어딘지도 모르는 산간에 언양이라는 땅이 있고 거기에 소년단이 있어 아침마다 일찍 일어나는 조기회(早起會)를 한다 하는 소식은 벌써 작년 봄부터그 곳 어린이 독자인 신고송(申孤松) 씨 외에 여러분으로부터 지어 보내는작문과 편지를 늘 보고 나는 재미있게 여겨 오고 있었습니다.그런데, 기쁜 일로는 내가 이번에 그 곳에 강연갔던 길에 그 재미있는 조기회에 참례하고 온 것입니다',
#  '산과 들에 쌓였던 흰 눈도 이제는 거의 다 녹았습니다 차갑게 불어와서 사람의 뺨과 귀를 베어갈 듯하던 바람도 차차 부드럽고 따뜻해졌습니다. 오랜 겨울 동안을 차고 무거운 땅속에서 꼼짝 못하고 웅크리고 숨어있던 예쁜 가락지꽃 나무 한 그루가 있었습니다',
#  '옛날 옛적 어느 깊은 산 속에 가난한 나무장수 노인이 있었습니다. 마나님도 없고, 아드님도 며느님도 없고, 다만 손녀 색시 세 사람만 데리고 있었습니다',
#  '옛날 옛날 오랜 옛날 까마귀 한 마리가 공작새 기죽지 털을 다섯 여섯 개 얻었습니다 그래서 그것을 자기의 시꺼먼 기죽지 사이에다가 꽂고 산속으로 날아가서 여러 새 들 앞에 가서 자랑을 하였습니다. “어떠냐 내 깃이야말로 참 훌륭하지?" 여러 새들은 참말 그 깃이 아름답고 훌륭한 데 놀라며 칭찬을 한 후에 드디어 까마귀를 새들 중의 임금님으로 삼았습니다',
#  '유쾌한 크리스마스가 돌아왔습니다. 어디든지 즐겁고 광명한 빛이 가득하였습니다',
#  '학교에서는 공부도 잘 하고, 품행이 얌전하여 5년급의 부급장인 칠성이는집안이 가난하여, 아버지가 반찬 가게를 하고 있으므로 학교에서 돌아만 가면 밤이 들기까지 가게의 심부름을 하느라고, 매일 고달프게 지내는 터였습니다.한 학교에 다니는 아이들이 가끔 가끔 길거리에서 칠성이가 비웃두름이나,미나릿단이나, 숯섬 같은 것을 지고 지게꾼처럼 사 가는 손님의 뒤를 따라가는 것을 보지마는 원래 공부도 잘 하고, 마음이 착하므로 아무도 그를 업신여기거나 놀리거나 하는 아이는 없었습니다',
#  '한 집에 도둑이 들어, 손에 칼을 들고 주인이 책을 읽고 있는 방에 가서,“꼼짝 말고 돈을 내놓아라.”하였습니다',
#  '옛날 옛날 아주 가까운 옛날, 웃지 마십시오. 지금으로부터 20년 전만 하여도 지금 생각하면 아주 태곳적 같은 옛날이어서, 그 때에 학교에 다니면서 보고 듣던 일, 내 몸으로 당하고 겪던 일 생각하면 지금도 가끔 혼자 웃을 때가 많습니다',
#  '왕비가 아드님 낳은 것을 알고 어디서 온 줄도 모르게 왕비의 앞에 나타난 작은 이는, “약속한 대로 그 아드님을 데리러 왔으니 어서 달라.”고 하였습니다',
#  '네모 반듯한 방 속에 초를 열두 개를 세우고, 모두 불을 켜 놓아서, 방 안이 몹시 밝았습니다. 첫째 촛불을 훅 불어 껐습니다',
#  '어느 시골 산 밑 동네에 바느질 잘 하고, 수 잘 놓는 어여쁜 총각이 있는데, 수를 놀 때마다 붉은 실, 노란 실 또는 파란 실, 초록실을 이로 물어서툭툭 끊게 되는 것이 자기 생각에도 미안하였습니다. 하루는 아기 버선에꽃수를 놓고 나서, 남은 실을 이로 물어 끊었는데, 그 실 끝이 혀 끝에 매어 달려서, 영영 떨어지지를 않습니다',
#  '싸늘한 바람이 건건히 불어오는 첫가을이었습니다. 여러 날 두고 비가 조금씩 오던 날이 겹겹이 싸였던 검은 구름까지 시원하게 벗겨지고 파란 하늘에 화려한 햇볕이 빤하게 빛나는 정여신이 번쩍 나는 날이었습니다',
#  '옛날 아시아의 중앙에 페르시아라는 강한 나라가 있었는데, 자기 나라의강한 것을 믿고 바다를 건너 희랍(그리스)을 들이쳤습니다.그 때, 희랍 남쪽 끝에는 스파르타라 하는 작은 나라가 있었으므로, 그 작은 스파르타 나라가 제일 먼저 페르시아의 많은 군사를 막아 싸우게 되었습니다',
#  '대단히 더운 날이니, 슬픈 이야기보다도 무서운 이야기보다도, 우습고 우습고 허리가 아프게 우스운 이야기를 하나 하지요.옛적 아주 어수룩한 옛적에 시골 양반 한 분이 서울 구경을 왔다가, 불만켜 대면 온 방안이 환하게 밝아지는 초를 처음 보고, 어찌 신기한지 많이사가지고 내려가서, 자기 동네의 집집마다 찾아가서, 서울 구경 이야기를자랑삼아 하고, 서울 갔던 표적으로 그 신기한 양초를 세 개씩 나눠 주었습니다',
#  '나는 이번에 경상도 울산에 갔던 길에 늘 보고 싶어 원하던 해녀의 살림구경을 하고 왔습니다.동화에 나오는 인어 아씨와 같이 사시 사철 물 속에 들어가 살면서 바다속에 있는 전복, 해삼, 청각, 미역, 문어 같은 것을 따 내오는 해녀 아씨들! 어려서부터 이 날까지 나는 어떻게 보고 싶어하였는지 모릅니다',
#  '오래 된 여러 백 년 된 옛날이었습니다.한적하고 고요한 시골에서만 자라는 나이 어린 사람들에게는, 늘 이야기로만 듣는 서울이 그립고, 그 서울에 있다는 모든 것, 모든 곳이 모두 그리웠습니다',
#  '어떤 산골에 조그만 초가집이 하나 있었습니다 집 울타리에는 새빨간 복숭아가 주렁주렁 달린 나무가 섰고 그 옆으로는 호박넝쿨이 한가히 뻗쳐 올라가 있는 고요하고 깨끗한 집이었습니다. 이 집에는 순애라고 하는 금년 열여섯 살 된 예쁜 소년와 순애의 늙은 할머님 두 식구가 살고 있었습니다',
#  '신년 새해는 소 해이니 소에 대한 우리나라 옛이야기에 관한 것을 하겠습니다. 벌써 오랜 옛날이었습니다',
#  '아기는 온종일 학교에서 유쾌하게 뛰어 놀고 집에 돌아와서는 동아리 아이들과 술래잡기와 널뛰기를 하였습니다. 새 댕기를 드린 기쁨과 새 옷 입은 기쁨과 어디를 가든지 설상 받는 기쁨과 함께 아기는 참말 즐겁게 기쁘게 놀았습니다',
#  '벌써 여러 해 전 일이었습니다. 쌀쌀한 바람 부는 섣달 어느 날 아침에,영국 리버풀이라는 항구에서 큰 기선 한 척이 먼 길을 떠나 출범하였습니다',
#  '늦은 가을, 깊은 산 어느 곳에 팥배 열매가 붉게 익어 있었답니다. 작은 새 한 마리가 와서“팥배나무님 고운 당여신의 열매 하나만 주세요',
#  '옛날 파사(페르시아)라는 나라에 마음성 착한 임금님이 한 분 있었는데,매양 대궐 바깥의 일반 세상 인심을 살피기 위하여, 남모르게 변복을 하고이 거리 저 거리를 행인들 틈에 섞여 돌아다니는데, 아무도 *그녀가 임금인 줄아는 사람이 없었습니다.하루는, 그 나라의 서울 시가의 끝에 있는 한적한 동네를 지나노라니까,한 느티나무 밑에 외따른 오막살이집이 있고 그 들창으로 젊은 여자들의 이야기 소리가 새어 나오므로 임금은 무슨 이야긴가 하고, 가깝게 가서 귀를기울여 들었습니다',
#  '옛날이었습니다. 서울 어떤 여관에는 상투를 틀어 붙이고, 굵다란 짚신을신은 시골뜨기 두 사람이 들었습니다',
#  '상철이는 신세 불쌍한 소녀가었습니다.충청 북도 청주에서 가난하게 살다가 아버지가 *그녀의 열두 살 되던 재작년에 병환으로 돌아가신 후로는 어머님과 어린 동생 수철이와 세 식구가 그냥살아갈 길이 도무지 없었습니다',
#  '기차 속에는 별별 사람이 한데 섞여 앉아서 먼 길을 갑니다. 신문을 읽고앉았는 사람도 있고, 팔짱을 끼고 남의 얼굴만 바라보는 사람도 있고, 담배를 퍽퍽 피우면서 옆에 있는 이에게 이야기를 거는 사람도 있습니다',
#  '따뜻한 봄날 꿀벌 한 마리가 이 꽃 저 꽃으로 돌아다니면서 꽃 속에 모여 있는 달콤한 꿀을 맛있게 먹었습니다. 날씨는 화창하고 사방에 꽃들은 얼마든지 많이 피었으므로 꿀벌은 마음이 대단히 유쾌하였습니다',
#  '봄이 왔습니다. 외로운 사람의 가슴을 더욱 쓸쓸하게 하는 봄이……',
#  '몹시 어두운 날 밤이었습니다. 도적 두 명이 어느 고래등같이 큰 집 담을넘어서 몰래 들어왔습니다',
#  '난쟁이 난쟁이 할아버지가 작은작은 오게 암탉을 길렀습니다. 작은 암탉은 또 작고 작은 닭의 알을 낳았습니다',
#  '요전 번에 발명왕 에디슨 선생의 이야기를 하지 않았습니까?그 에디슨 선생이 하루는 친한 친구들에게 ‘저녁 밥을 같이 먹자.’고 청해 왔습니다',
#  '요전번 유럽에 일어났던 세계 대전쟁이 끝난 후에 여러 곳에서 독립국이된 조그만 나라가 많은 중에 ‘유태’라는 나라가 있었습니다.이 유태라는 나라는 퍽 오래된 역사를 가진 나라인데 유명한 예수님도 이나라에서 탄생하였고, 예수님 나기보다도 훨씬 예전, 지금으로부터 한 삼천년 전에는 이 나라에 삼손이라는 굉장한 기운을 가진 장사가 나왔습니다',
#  '모이를 찾아 수탉 한 마리가 오양간 앞으로 옵니다. 그때가 점심때라서 닭은 먼 데서 들리어 오는 동무 소리를 받아 앙가슴을 탁 벌리고 길게 목을 빼어 한바탕 울었습니다',
#  '옛날 어떤 산속에 몹시 기운이 세고 사나운 사자가 한 마리 있었습니다. 사자는 자기 기운 있는 것만 믿고 산속에 사는 짐승을 만나는 대로 잡아먹고 죽이고 하는고로 여러 짐승은 언제든지 기를 펴고 지내지 못하였습니다',
#  '한 나그네가 길을 가다가 날이 저물어서, 길가 집에 하룻밤 자고 가기를청하였더니, 있는 사랑에 거절하지는 못하고, 들어앉게는 하나, 인사하는투로 보거나 여러 가지가 친절하지 못하고, 거만스럽고 야릇한지라 대단히불쾌한데, 한방에 먼저 와 앉은 손님은 이 집 주인의 새 사돈이라 하여, *그녀에게만 대접을 융숭하게 하므로 나그네가,“이 주인놈이 나중에 밥상을 층하를 지어, 저 사돈은 잘 먹이고, 나는 아무렇게나 먹일 눈치로구나!”생각하고 있었습니다.이윽고 주인이 안으로 들어가더니, 머슴을 시켜서 사돈의 밥상을 먼저 썩잘 차려 내 보내므로, 나그네가 사돈보다 먼저 일어나면서,“나는 먼 길 오느라고 시장하여서, 실례지만 먼저 먹습니다',
#  '농사가 그리 잘 되지는 못했으나, 가을이 되어 만곡이 익으매 그래도 농가에서들은 기쁜 마음으로 벼를 베느라고 바빴습니다.성칠이도 동네 사람들의 조력을 얻어 가지고 자기 논의 벼를 베어서, 논두덕에 널어 두었습니다',
#  '센 강을 건너가는 나룻배에 조그만 어린 거지 두 사람이 여러 손님 옆 한구석에 앉아 있습니다.한 사람은 열 살쯤 된 소녀가고, 한 사람은 열한 살 되어 보이는 소녀인데둘은 서로 모르는 사이였으나 각각 남의 문 앞으로 노래를 부르면서 돈을구걸하러 다니는 같은 신세였습니다',
#  '물기가 듣는 듯 그늘 짙은 뒷마루에서 업<인물38>는 바느질이 자지러졌다.(음력으로 칠월) 한여름의 한낮은 늘어지게 길다',
#  '어떤 산 아래 커다란 바위가 하나 서 있습니다. 그런데 그 바위 속에는 세상에도 제일 귀하고 중한 금강석이 한 개 박혀 있었습니다',
#  '오스트리아와 전쟁할 때, 그 때의 불란서의 군대에는 한 사람 17세 되는소년 고수(북 치는 사람)가 있어서, 사령관의 명령대로 호령 대여신의 북을울리어 군대를 전진시키고 있었습니다.그러나, 다른 부대와의 연락이 끊어지고, 외롭게 떨어진 군대였으므로 처음에는 모르고 자꾸 전진하다가 몹시 수많은 오스트리아 본군을 만나 큰 변을 당하게 되었습니다',
#  '옛날 어느 바닷가에 조그만 어촌이 있었습니다 이곳에 사는 사람들은 어려서부터 바다에서 자라나서 배젓기와 헤엄치기를 잘하였습니다. 어떤 첫 겨울날이었습니다',
#  '옛날 중국 강서라고 하는 땅에 유명한 점쟁이가 하나 있었습니다. 그런데,그 때 그 강서 땅을 다스려 나가는 원이, 이 점쟁이를 한 번 시험해 보기위하여 자기 아내 이외의 여섯 사람의 색시에게 똑같이 입히고 또 머리도 똑같이 땋고, 신발까지 똑같은 것을 신긴 후, 그 점쟁이를 불러서,“자, 어느 색시가 내 아내인 것을 알아내어라',
#  '불란서에 렘네라 하는 유명한 문학자가 있었습니다. *그녀가 나라의 미움을받아 쓸쓸하고 외딴 곳에 귀양살이를 하고 있을 때, 불행히 목병이 크게 나서 고생을 하던 때 일이었습니다',
#  '어느 숲 속에 참새 부부가 있어서, 근처에 있는 개구리와 딱다구리를 동무 삼아 친하게 지내고 있었습니다.하루는 참새 부부가 양식을 구하러 멀리 나갔다가 돌아와 보니, 성질 나쁜큰 곰 한 마리가 와서, 참새집 지어논 나무 밑동을 흔들어서 참새집과 그속에 낳아 논 귀여운 알들을 모두 쪼아 놓고, 그 큰 발로 짓밟아 버리면서자못 유쾌한 듯이 웃고 있었습니다',
#  '해는 인정스럽게 하늘 한가운데서 따스하게 웃고 그 웃음을 받은 숲은 활발스럽게 자랍니다. 바람이 스르르 지나면 즐거움에 우줄거리고뭇 새들은 봄노래를 소리껏 부릅니다',
#  '이십 년 전 실지로 있었던 이야기입니다.북아메리카 캐나다에 있는 캐나다 태평양 철도 회사의 밴쿠버 정거장에서여러 100명의 남녀 손님을 태운 기차가 이제(이 쪽 태평양 가를 떠나) 여러날 두고 달음질하여, 저 쪽 대서양 가<인물201> 먼 길을 다녀오려고 모든 준비를마치었습니다',
#  '소녀 에르지가 열한 살 되는 해 생일날 밤이었습니다. 밖에는 캄캄한 밤인데 비가 주룩주룩 오고 있었습니다',
#  '영길의 집에서는 한 달 전에 검둥이가 새끼를 낳았습니다. 그런데 두 마리는 어미 개를 닮은 검둥이요, 한 마리는 얼룩이었습니다',
#  '어느 동리에 과수원이 잔뜩 있고 그 과수원에는 온갖 과실 나무가 가득 채워 있었습니다.봄이 되면 고운 꽃이 피고, 새들이 재미있게 이 가지 저 가지로 날아다니며, 좋아라고 울고 있었습니다',
#  '예전 독일 나라에 프리<인물132>히라는 대여왕이 있었는데, 싸움 잘하고 지혜 많기로도 유명하였지마는, 독일 나라의 기초를 튼튼히 세운 유명한 임금이었습니다.일곱 해 동안 전쟁을 하는 동안에 한 번도 싸움에 진 일이 없으므로, 이것을 시기하는 나라에서 싸움으로는 도저히 이길 수가 없으니까, 어떻게 하든지 꾀라도 써서, 대왕을 죽이려 하였습니다',
#  '한 산 속에 암자에 덕이 높은 선생님이 있어서, 각 처에서 그 제자가 되기를 바라고 따라와서, 공부를 하고 있는 젊은이들이 아홉 분이 있었습니다.그런데, 그 중에 한 사람이 공부가 아직 부족하고 욕심이 많아서, 남의 붓이나 주머니칼 같은 것을 넌지시 집어 가지는 버릇이 있었습니다',
#  '아주 오랜 옛날 중국 사여신이, 용수철같이 꾸부러진 이상스러운 구슬 한 개를 가지고, 조선에 건너와서 거기에다 굵은 노끈을 꿰어 보라고 하였습니다.그 때, 대궐 안에는 유명하다는 학자들은 모두 모여 앉아서, 그 이상스러운 구슬에 노끈 꿸 궁리를 해 보고 해 보았지마는 도무지 좋은 꾀가 나서지를 않았습니다',
#  '현대 문명은 전기가 낳았다 하는 것인데 그 전기를 발명한 이는 미국 사람 프랭클린이니, 현대의 세계 문명은 프랭클린이 낳아 놓았다 할 것입니다.그 프랭클린이 젊어서 인쇄소를 하는 한편, 고서적 상점을 경영하는데, 하루는 서점에 손님 한 분이 와서 1원짜리 헌책을 집어 들고,“이것을 75전에 팔라',
#  '옛날에 우리나라 유명한 양반으로 팔도어사를 지냈던 박문수란 분이 있었습니다 그분이 조선팔도를 돌아다니면서 별별 기괴한 일을 많이 당하였는 . 데 그중에 한 가지 재미있는 이야기를 하지요',
#  '퍽 오래 된 옛날에 사실로 있었던 이야기입니다.마음 착한 김 씨 한 분이 무근(사실에 없는 일, 근거가 없다는 말)의 죄명을 입어서 감옥에 갇히었습니다',
#  '솔로몬이라 하면 옛날 서양에 있던 여러 왕들 중에서 가장 지혜 많기로 유명한 여왕이었습니다.*그녀는 유태 나라의 왕 다윗의 딸이었는데, 어려서부터 지혜가 많았습니다',
#  '여러분 이 국기 소녀라는 이야기를 하기 전에 한 가지 기억해둘 것이 있습니다. 이야기는 저 멀고 먼 불란서라는 나라의 예쁘고 재미있는 이야기인데 그 나라 국기는 푸른 빛 흰 빛 붉은 빛의 세 가지 빛으로 줄이 진 것입니다',
#  '나는 잠수부가 되어 바닷속 물 속에서 17년 동안이나 살았으므로, 지금은 그 깊은 바닷속이 내 고향의 정든 본집과같습니다.그 무겁고, 퉁퉁한 잠수복을 입고, 무엇 하러 바닷속에 들어가는고 하니,커다란 기선이 파선되어, 물 속에 잠겨 버린 것을 꺼내러 들어가는 일이 제일 많습니다',
#  '어느 청명하고 따뜻한 봄날이었습니다. 무르녹는 봄빛을 따라 젊은 청년 남녀들은 한 떼 한 떼가 몰려 산으로 들로 공원으로 행길로 유쾌하게 이야기하면서 산보를 다닙니다',
#  '“전교 학생은 운동장으로 집합하라!”는 교장의 명령이 졸지에 내렸습니다.‘하학하여 돌아갈 시간인데 무슨 일일까, 무슨 일일까?’하고, 4백여 명 학생이 궁금해 하면서, 운동장 복판에 반반이 열을 지어 늘어섰더니, 한 열에 선생 한 분씩이 달려들어 끝에서부터 차례로 여학생의 주머니를 뒤지기 시작하였습니다',
#  '두 달 전부터 준비하여 오고, 한 달 전부터 연습을 하여 오던 추기 운동회가 단 하룻밤을 격하였을 뿐이므로, 이 날은 벌써 그 넓은 교정이 천막과 붉은 장막과 만국기로 덮였습니다. 울긋불긋한 장식으로 그득 찬 운동장과 같이 어린 학생들의 가슴도 기쁨에 그득하여 공연히 어깨가 으쓱으쓱하고 마음이 조용치를 않아서 저녁밥도 잘 안 먹고 가로로 나섰습니다',
#  '창남이와 창용이에게 아저씨가 참외를 반 개씩 깎아 주었습니다.창남이와 창용이는 나이도 동갑이요, 무엇이든지 서로 지기를 싫어하는 터이라, 남의 것이 자기 것보다 크지나 않은가 하여 서로 서로 참외를 비교해보더니, 창용이가 먼저 상을 찡그리고,“창남이 것이 내것보다 더 큰데, 왜 나는 조그만 것을 주었어요',
#  '어떤 호숫가에 토끼가 여러 마리 살고 있었습니다. 그런데 어떤 해에는 코끼리 떼들이 매일 이 호숫가로 물을 먹으러 옴으로 약한 토끼들은 항상 코끼리 발에 밟혀 벌써 여러 마리가 죽었습니다',
#  '가린은 비행기를 잔뜩 높이 띄어 가지고 캄차카 반도에 있는 페트로파블로프스크 시로 향하여 갔습니다. 떠난 지 얼마 못되어 벌써 목적지에 이르러비행기가 점점 땅에 내리기를 시작할 때에 별안간 큰 바람이 일어났습니다',
#  '하늘에서 작대기 한 개가 떨어져서 우뚝 섰는데 작대기 머리 위에 제비 한마리가 와 앉았습니다. 작대기는 덜컥 넘어졌습니다',
#  '마음 정직한 농부가 이웃집에서 돈 50전을 취해다 쓰고 갚겠다던 날에 돈이 없으니까 하는 수 없어서, 암탉 한 마리를 돈 대신으로 갖다 주었습니다. 그 후 2, 3일이 지나서 농부 내외는 밭에 일하러 나가고, 일곱 살 먹은딸이 혼자 집을 보고 있는데, 이웃집에 갖다 준 암탉이 와서, 전에 알 낳던 둥우리에 올라가서 커다란 알을 낳아 놓고 갔습니다',
#  '새해는 호랑이 해입니다. 호랑이에 대한 이야기는 우리나라에 많이 있는데 이것은 여러분이 아직 듣지 못하던 새 이야기입니다',
#  '불란서의 유명한 학자 몬좌드 박사는 젊었을 때부터 학문에 어떻게 열심이었던지, 무슨 연구를 할 때에는 다른 일은 전혀 모르고 지냈습니다.하루는 무슨 급한 볼일이 있어서, 잠깐 동안 어디를 갔다 올 터인데, 그동안에 누가 찾아왔다가 헛걸음을 하고 돌아가면 미안하겠으므로, 자기 연구실 문에다가,나는 한 시간쯤 후이면 돌아올 터이니, 나를 찾아오신 분은 이 방문 앞 걸상에 앉으셔서, 기다려 주십시오',
#  '구차하고 빈한한 사람들만 사는 빈민굴 동리 어구에서 학교에도 못 가는 가련한 아이들이 버선도 신발도 못 신고 맨발로 나와서 장난감 하나 없이뛰어놀고 있는데, 그 쓸쓸스럽게 노는 꼴을 아까부터 물끄러미 서서 보는남자가 한 분 있었습니다. 입은 의복도 너절하고, 모자도 신발도 너절하면서 주머니에는 무엇을 넣었는지 퉁퉁한데 여기서도 저기서도 허리를 굽혀서 무언지 자꾸 집어서는 주머니에 넣고 넣고 하고 있었습니다',
#  '아버지를 찾으려고 산 설고 물 설은 대판까지 간 불쌍한 소녀 순희가 의외로 아버님이 석탄광이 무너져서 치어 죽었다는 눈물겨운 편지를 개성 있는 창렬이에게 하였으나 창렬이는 그때 그 편지를 받지 못하고 개성에 있지 않았으니 과연 창렬이는 어디를 갔겠습니까? 씩씩한 기운으로 전조선육상경기대회를 마치고 난 창렬이는 완고한 부모님이 허락은 안 하시나 기어이 훌륭한 사람이 되어야 하겠다는 생각으로 5월 일 바로 순희가 편지한 지 사흘 전에 개성을 떠났습니다 20 ! . 부모님에게 알리지도 않고 허락도 없이 아버님이 일가 집에 갖다주라는 돈 원을 가지고 떠난 것이었습니다 60 ',
#  '늦은 가을입니다. 산언덕 밭귀에 낮잠 자던 호박이 눈을 뜨자 옆에 자는호박을 깨웠습니다',
#  '하늘도 슬픈 일이 있는 듯이 음산하고 추운 흐린 날이었습니다. 하얀 눈이펄펄 내리기 시작하는데, 행인도 적은 동리 밖 신작로로 하잘것없이 엉성한상여 한 채가 지나갔습니다',
#  '하늘도 슬픈 일이 있는 듯이 음산하고 추운 흐린 날이었습니다. 하얀 눈이펄펄 내리기 시작하는데, 행인도 적은 동리 밖 신작로로 하잘것없이 엉성한상여 한 채가 지나갔습니다',
#  '볼그레한 꽃<인물16>같이 어여쁘고 탐스럽던 뻬시의 얼굴은 몇 달이나 앓고 난사람처럼 양초 빛같이 파랗고 해쓱하였습니다. 그리고, 눈물에 부은 듯 <인물70> 산머리에 넘어가는 저녁 해를 원망스럽게 바라보면서 한숨만 덧없이쉬고서 섰습니다',
#  '발명왕으로 유명한 에디슨이 자기 부인과 혼인 예식을 할 때의 일입니다.식장에는 벌써 중매쟁이와 *그녀의 친척과 또 동무들이 구름같이 모여 섰고,목사는 지금 막 두 사람 사이에 아주 부부가 되는 맨 마지막 맹세를 시켜주려 할 때인데, 그 때 돌연히 에디슨의 머리 속에는 이 때까지 영영 생각이 나지않던, 무슨 기계 발명에 대한 좋은 고안이 머리에 떠올랐습니다',
#  '사무실에서 한창 바쁘게 일을 보고 있는데 집에서 아이들이 몰려와 어디로든지 놀러 가자고 졸라댔습니다.그들은 나를 자기네 동무 가운데 그 중 친하고 그 중 만만한 동무로 알므로 그날도 나는 그들의 청을 아니 들어 줄 수 없어, 장충단으로 가서 미끄럼도 타고 흙장난도 하고 재미있게 놀았습니다',
#  '지독히도 더운 7월의 마지막 날이었다. 거리의 사람들은 연신 손부채질을 하며 얼굴을 찡그렸다',
#  '핸드폰 게임 앱을 <인물153>자 선물상자가 나왔다. 선물상자가 열리면서 수많은 옷들과 폭죽들이 휘날리더니, 마지막에 내 아바타가 나와서 인사를 해주었다',
#  '그럭저럭 사이좋은 부부가 있었어요. 둘은 같이 식탁을 차렸고, 저녁을 먹은 뒤에는 산책도 빼놓지 않았지요',
#  '비가 개었다.  동시에 저 편 들판 건너 숲 뒤에는 둥그렇게 무지개가 뻗쳤다',
#  '여름 장이란 애시당초에 글러서 해는 아직 중천에 있건만 장판은 벌써 쓸쓸하고 더운 햇발이 벌려 놓은 전휘장 밑으로 등줄기를 훅훅 볶는다. 마을 사람들은 거의 돌아간 뒤요, 팔리지 못한 나무꾼패가 길거리에 궁싯거리고들 있으나 석유병이나 받고 고깃마리나 사면 족할 이 축들을 바라고 언제까지든지 버티고 있을 법은 없다',
#  '생물 시간이었다.  “이 없는 동물이 무엇인지 아는가?”  선생이 두 번씩 거푸 물어도 손 드는 학생이 없더니 별안간 “넷!” 소리를 지르면서 기운 좋게 손을 든 사람이 있었다']

# %%
labeled_df = df.assign(label = labels)
labeled_df.rename(columns = {'동화':'target'},inplace=True)
labeled_df
# Out:
#                                                 target  \
# 0    "나는 알쏭달쏭 미술관 관장 '<인물0>'란다. 이곳은 신기하고 괴상한 작품으로 가...
# 1    <인물1>은 어려서부터 책을 참 좋아했어요. 다섯 살 때는 할머니한테 천재문을 배웠...
# 2    텔레비전도 재미있는 그림책도 없었던 옛날의 어린이들은 무엇을 하고 놀았을까요? "옛...
# 3    "따뜻한 봄바람이 살랑살랑 불고 겨울에 움츠렸던 몸이 움찔움찔. 얘들아 나랑 놀자 ...
# 4    우리 할아버지입니다. 어려서부터 나는 할머니와 한 방을 썼어요. 할머니는 늘 신문을...
# ..                                                 ...
# 771  핸드폰 게임 앱을 <인물153>자 선물상자가 나왔다. 선물상자가 열리면서 수많은 옷...
# 772  그럭저럭 사이좋은 부부가 있었어요. 둘은 같이 식탁을 차렸고, 저녁을 먹은 뒤에는 ...
# 773  비가 개었다.  동시에 저 편 들판 건너 숲 뒤에는 둥그렇게 무지개가 뻗쳤다. 오묘...
# 774  여름 장이란 애시당초에 글러서 해는 아직 중천에 있건만 장판은 벌써 쓸쓸하고 더운 ...
# 775  생물 시간이었다.  “이 없는 동물이 무엇인지 아는가?”  선생이 두 번씩 거푸 물...
#
#                                                  label
# 0    "나는 알쏭달쏭 미술관 관장 '<인물0>'란다. 이곳은 신기하고 괴상한 작품으로 가득하지
# 1      <인물1>은 어려서부터 책을 참 좋아했어요. 다섯 살 때는 할머니한테 천재문을 배웠죠
# 2    텔레비전도 재미있는 그림책도 없었던 옛날의 어린이들은 무엇을 하고 놀았을까요? "옛...
# 3    "따뜻한 봄바람이 살랑살랑 불고 겨울에 움츠렸던 몸이 움찔움찔. 얘들아 나랑 놀자 ...
# 4                   우리 할아버지입니다. 어려서부터 나는 할머니와 한 방을 썼어요
# ..                                                 ...
# 771  핸드폰 게임 앱을 <인물153>자 선물상자가 나왔다. 선물상자가 열리면서 수많은 옷...
# 772  그럭저럭 사이좋은 부부가 있었어요. 둘은 같이 식탁을 차렸고, 저녁을 먹은 뒤에는 ...
# 773         비가 개었다.  동시에 저 편 들판 건너 숲 뒤에는 둥그렇게 무지개가 뻗쳤다
# 774  여름 장이란 애시당초에 글러서 해는 아직 중천에 있건만 장판은 벌써 쓸쓸하고 더운 ...
# 775  생물 시간이었다.  “이 없는 동물이 무엇인지 아는가?”  선생이 두 번씩 거푸 물...
#
# [776 rows x 2 columns]

# %%
labeled_df.to_csv('labeld_dataset_0902.csv')
